# %% [markdown]
# ## Goal: use of everything we've learned about APIs, databases, and Object-Oriented Programming to Extract, Transform, and Load (or ETL, for short) some data from a SQL database into a MongoDB Database.
#
# Upon completion of this lab, each unique team in this dataset should have a record in the MongoDB instance containing the following information:
#
# - 1. The name of the team
# - 2. The total number of goals scored by the team during the 2011 season
# - 3. The total number of wins the team earned during the 2011 season
# - 4. A histogram visualization of the team's wins and losses for the 2011 season (store the visualization directly)
# - 5. The team's win percentage on days where it was raining during games in the 2011 season.

# %% [markdown]
# Using Object-Oriented Programming is a requirement for this project--you must create at least 2 separate, well structured classes in your solution! Although it may seem easier to "just start coding", this is a classic beginner's mistake. Instead, think about separating out the different functionalities you'll need to reach your goal, and then build classes to handle each. For instance, at minimum, you'll need to:
#
# - Query the SQL database
# - Calculate summary statistics
# - Get the weather data from the DarkSky API
# - Load the data into MongoDB
#
# We strongly recommend you consider creating separate classes for handling at least some of these of these tasks. Be sure to plan the inputs, outputs, and methods for each class before you begin coding!

# %% [markdown]
# ## Inspect Database.sqlite

# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import pandas
import re
import datetime
import time
import re
import json
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
conn = sqlite3.connect('database.sqlite.db')
c = conn.cursor()

# %%
c.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(c.fetchall())
# Out:
# [('sqlite_sequence',), ('Matches',), ('Teams_in_Matches',), ('Teams',), ('Unique_Teams',), ('results',)]

# %%
tables = list(c.execute("SELECT name FROM sqlite_master WHERE type='table';").fetchall())
tables
# Out:
# [('sqlite_sequence',),
#  ('Matches',),
#  ('Teams_in_Matches',),
#  ('Teams',),
#  ('Unique_Teams',),
#  ('results',)]

# %%
c.execute("SELECT name, type FROM sqlite_master;")
print(c.fetchall())
# Out:
# [('sqlite_sequence', 'table'), ('Matches', 'table'), ('sqlite_autoindex_Matches_1', 'index'), ('Teams_in_Matches', 'table'), ('Teams', 'table'), ('Unique_Teams', 'table'), ('FlatView_Chrono_TeamOrder_Reduced', 'view'), ('FlatView_Advanced', 'view'), ('FlatView', 'view'), ('results', 'table')]

# %%
c.execute('''select * from sqlite_sequence;''')
c.description
# Out:
# (('name', None, None, None, None, None, None),
#  ('seq', None, None, None, None, None, None))

# %%
c.execute('''select * from sqlite_sequence;''')
df1 = pd.DataFrame(c.fetchall())
df1.columns = [x[0] for x in c.description]

# %%
df1
# Out:
#            name    seq
# 0       Matches  46774
# 1  Unique_Teams    128

# %%
c.execute('''select * from Teams_in_Matches;''')
df2 = pd.DataFrame(c.fetchall())
df2.columns = [x[0] for x in c.description]
print(len(df2))
df2.head()
# Out:
# 49148
#    Match_ID  Unique_Team_ID
# 0         1              26
# 1         1              46
# 2         2              26
# 3         2              42
# 4         3              26

# %% [markdown]
# Table: Teams_in_Matches
#
# - Match_ID (int): Unique match ID
# - Unique_Team_ID (int): Unique team ID (This table is used to easily retrieve each match a given team has played in)

# %%
c.execute('''select * from Teams;''')
df3 = pd.DataFrame(c.fetchall())
df3.columns = [x[0] for x in c.description]
print(len(df3))
df3.head()
# Out:
# 468
#   Season       TeamName KaderHome AvgAgeHome ForeignPlayersHome  \
# 0   2017  Bayern Munich        27         26                 15
# 1   2017       Dortmund        33         25                 18
# 2   2017     Leverkusen        31         24                 15
# 3   2017     RB Leipzig        30         23                 15
# 4   2017     Schalke 04        29         24                 17
#
#   OverallMarketValueHome AvgMarketValueHome StadiumCapacity
# 0              597950000           22150000           75000
# 1              416730000           12630000           81359
# 2              222600000            7180000           30210
# 3              180130000            6000000           42959
# 4              179550000            6190000           62271

# %% [markdown]
# Table: Teams
#
# - Season (str): Football season for which the data is valid
# - TeamName (str): Name of the team the data concerns
# - KaderHome (str): Number of Players in the squad
# - AvgAgeHome (str): Average age of players
# - ForeignPlayersHome (str): Number of foreign players (non-German, non-English respectively) playing for the team
# - OverallMarketValueHome (str): Overall market value of the team pre-season in EUR (based on data from transfermarkt.de)
# - AvgMarketValueHome (str): Average market value (per player) of the team pre-season in EUR (based on data from transfermarkt.de)
# - StadiumCapacity (str): Maximum stadium capacity of the team's home stadium

# %%
c.execute('''select * from Unique_Teams;''')
df4 = pd.DataFrame(c.fetchall())
df4.columns = [x[0] for x in c.description]
print(len(df4))
df4.head()
# Out:
# 128
#         TeamName  Unique_Team_ID
# 0  Bayern Munich               1
# 1       Dortmund               2
# 2     Leverkusen               3
# 3     RB Leipzig               4
# 4     Schalke 04               5

# %% [markdown]
# Table: Unique Teams
#
# - TeamName (str): Name of a team
# - Unique_Team_ID (int): Unique identifier for each team

# %%
c.execute('''select * from Matches;''').description
# Out:
# (('Match_ID', None, None, None, None, None, None),
#  ('Div', None, None, None, None, None, None),
#  ('Season', None, None, None, None, None, None),
#  ('Date', None, None, None, None, None, None),
#  ('HomeTeam', None, None, None, None, None, None),
#  ('AwayTeam', None, None, None, None, None, None),
#  ('FTHG', None, None, None, None, None, None),
#  ('FTAG', None, None, None, None, None, None),
#  ('FTR', None, None, None, None, None, None))

# %% [markdown]
# Table: Matches
#
# - Match_ID (int): unique ID per match
# - Div (str): identifies the division the match was played in (D1 = Bundesliga, D2 = Bundesliga 2, E0 = English Premier League)
# - Season (int): Season the match took place in (usually covering the period of August till May of the following year)
# - Date (str): Date of the match
# - HomeTeam (str): Name of the home team
# - AwayTeam (str): Name of the away team
# - FTHG (int) (Full Time Home Goals): Number of goals scored by the home team
# - FTAG (int) (Full Time Away Goals): Number of goals scored by the away team
# - FTR (str) (Full Time Result): 3-way result of the match (H = Home Win, D = Draw, A = Away Win)

# %%
c.execute('''select * from Matches where season = 2011 order by date;''')
dfm = pd.DataFrame(c.fetchall())
dfm.columns = [x[0] for x in c.description]
print(len(dfm))
dfm.head(100)
# Out:
# 992
#     Match_ID Div  Season        Date            HomeTeam            AwayTeam  \
# 0       1133  D2    2011  2011-07-15             Cottbus             Dresden
# 1       1167  D2    2011  2011-07-15      Greuther Furth       Ein Frankfurt
# 2       1551  D2    2011  2011-07-15       Frankfurt FSV        Union Berlin
# 3       1550  D2    2011  2011-07-16      Erzgebirge Aue              Aachen
# 4       1678  D2    2011  2011-07-16            St Pauli          Ingolstadt
# 5       1146  D2    2011  2011-07-17           Karlsruhe            Duisburg
# 6       1442  D2    2011  2011-07-17        Braunschweig         Munich 1860
# 7       1602  D2    2011  2011-07-17       Hansa Rostock           Paderborn
# 8       1360  D2    2011  2011-07-18  Fortuna Dusseldorf              Bochum
# 9       1505  D2    2011  2011-07-22            Duisburg             Cottbus
# 10      1596  D2    2011  2011-07-22          Ingolstadt      Erzgebirge Aue
# 11      1667  D2    2011  2011-07-22              Bochum       Frankfurt FSV
# 12      1261  D2    2011  2011-07-23         Munich 1860           Karlsruhe
# 13      1525  D2    2011  2011-07-23        Union Berlin      Greuther Furth
# 14      1390  D2    2011  2011-07-24             Dresden       Hansa Rostock
# 15      1574  D2    2011  2011-07-24              Aachen        Braunschweig
# 16      1699  D2    2011  2011-07-24           Paderborn  Fortuna Dusseldorf
# 17      1463  D2    2011  2011-07-25       Ein Frankfurt            St Pauli
# 18      1219  D1    2011  2011-08-05            Dortmund             Hamburg
# 19      1545  D2    2011  2011-08-05            St Pauli              Aachen
# 20      1613  D2    2011  2011-08-05        Union Berlin           Paderborn
# 21      1684  D2    2011  2011-08-05  Fortuna Dusseldorf          Ingolstadt
# 22      1130  D2    2011  2011-08-06      Greuther Furth             Dresden
# 23      1194  D1    2011  2011-08-06            Augsburg            Freiburg
# 24      1237  D1    2011  2011-08-06       Werder Bremen      Kaiserslautern
# 25      1292  D1    2011  2011-08-06              Hertha            Nurnberg
# 26      1311  D1    2011  2011-08-06           Stuttgart          Schalke 04
# 27      1433  D2    2011  2011-08-06             Cottbus         Munich 1860
# 28      1466  D1    2011  2011-08-06             FC Koln           Wolfsburg
# 29      1648  D1    2011  2011-08-06            Hannover          Hoffenheim
# ..       ...  ..     ...         ...                 ...                 ...
# 70      1278  D1    2011  2011-08-20           Stuttgart          Leverkusen
# 71      1295  D1    2011  2011-08-20            Dortmund            Nurnberg
# 72      1354  D2    2011  2011-08-20        Union Berlin              Bochum
# 73      1598  D2    2011  2011-08-20        Braunschweig      Erzgebirge Aue
# 74      1650  D1    2011  2011-08-20            Augsburg          Hoffenheim
# 75     44504  E0    2011  2011-08-20             Arsenal           Liverpool
# 76     44505  E0    2011  2011-08-20         Aston Villa           Blackburn
# 77     44506  E0    2011  2011-08-20             Chelsea           West Brom
# 78     44507  E0    2011  2011-08-20             Everton                 QPR
# 79     44508  E0    2011  2011-08-20          Sunderland           Newcastle
# 80     44509  E0    2011  2011-08-20             Swansea               Wigan
# 81      1163  D2    2011  2011-08-21       Frankfurt FSV       Ein Frankfurt
# 82      1257  D2    2011  2011-08-21             Cottbus           Karlsruhe
# 83      1312  D1    2011  2011-08-21               Mainz          Schalke 04
# 84      1404  D1    2011  2011-08-21            Hannover              Hertha
# 85      1607  D2    2011  2011-08-21             Dresden           Paderborn
# 86     44510  E0    2011  2011-08-21              Bolton            Man City
# 87     44511  E0    2011  2011-08-21             Norwich               Stoke
# 88     44512  E0    2011  2011-08-21              Wolves              Fulham
# 89      1150  D2    2011  2011-08-22            St Pauli            Duisburg
# 90     44513  E0    2011  2011-08-22          Man United           Tottenham
# 91      1142  D2    2011  2011-08-26            Duisburg             Dresden
# 92      1316  D1    2011  2011-08-26              Hertha           Stuttgart
# 93      1394  D2    2011  2011-08-26          Ingolstadt       Hansa Rostock
# 94      1523  D2    2011  2011-08-26              Bochum      Greuther Furth
# 95      1104  D1    2011  2011-08-27      Kaiserslautern       Bayern Munich
# 96      1109  D1    2011  2011-08-27          Leverkusen            Dortmund
# 97      1191  D1    2011  2011-08-27             Hamburg             FC Koln
# 98      1345  D1    2011  2011-08-27          Hoffenheim       Werder Bremen
# 99      1482  D1    2011  2011-08-27            Freiburg           Wolfsburg
#
#     FTHG  FTAG FTR
# 0      2     1   H
# 1      2     3   A
# 2      1     1   D
# 3      1     0   H
# 4      2     0   H
# 5      3     2   H
# 6      3     1   H
# 7      1     2   A
# 8      2     0   H
# 9      1     2   A
# 10     0     0   D
# 11     1     0   H
# 12     2     1   H
# 13     0     4   A
# 14     1     1   D
# 15     0     2   A
# 16     1     1   D
# 17     1     1   D
# 18     3     1   H
# 19     3     1   H
# 20     3     0   H
# 21     4     1   H
# 22     1     0   H
# 23     2     2   D
# 24     2     0   H
# 25     0     1   A
# 26     3     0   H
# 27     0     5   A
# 28     0     3   A
# 29     2     1   H
# ..   ...   ...  ..
# 70     0     1   A
# 71     2     0   H
# 72     2     1   H
# 73     1     1   D
# 74     0     2   A
# 75     0     2   A
# 76     3     1   H
# 77     2     1   H
# 78     0     1   A
# 79     0     1   A
# 80     0     0   D
# 81     0     4   A
# 82     2     0   H
# 83     2     4   A
# 84     1     1   D
# 85     1     2   A
# 86     2     3   A
# 87     1     1   D
# 88     2     0   H
# 89     2     1   H
# 90     3     0   H
# 91     3     0   H
# 92     1     0   H
# 93     3     1   H
# 94     1     4   A
# 95     0     3   A
# 96     0     0   D
# 97     3     4   A
# 98     1     2   A
# 99     3     0   H
#
# [100 rows x 9 columns]

# %% [markdown]
# ## Date data for API

# %%
c.execute('''select Date from Matches where season = 2011 order by date;''')
dfd = pd.DataFrame(c.fetchall())
dfd.columns = [x[0] for x in c.description]
print(len(dfd))
#dfd.head(100)
# Out:
# 992

# %%
dfdate = pd.DataFrame(dfd.Date.unique())

# %%
dfdate.columns = ["Date"]

# %%
dfdate.head()
# Out:
#          Date
# 0  2011-07-15
# 1  2011-07-16
# 2  2011-07-17
# 3  2011-07-18
# 4  2011-07-22

# %%
df[df['HomeTeam']== 'Aachen']
# Out:
#      Match_ID Div  Season        Date HomeTeam            AwayTeam  FTHG  \
# 15       1574  D2    2011  2011-07-24   Aachen        Braunschweig     0
# 46       1507  D2    2011  2011-08-13   Aachen             Cottbus     0
# 102      1702  D2    2011  2011-08-27   Aachen  Fortuna Dusseldorf     0
# 167      1529  D2    2011  2011-09-18   Aachen      Greuther Furth     0
# 206      1662  D2    2011  2011-09-30   Aachen       Frankfurt FSV     1
# 281      1682  D2    2011  2011-10-23   Aachen          Ingolstadt     3
# 335      1148  D2    2011  2011-11-06   Aachen            Duisburg     2
# 418      1446  D2    2011  2011-12-04   Aachen         Munich 1860     2
# 449      1595  D2    2011  2011-12-11   Aachen      Erzgebirge Aue     1
# 580      1465  D2    2011  2012-02-04   Aachen            St Pauli     2
# 640      1386  D2    2011  2012-02-19   Aachen       Hansa Rostock     0
# 681      1606  D2    2011  2012-03-03   Aachen           Paderborn     0
# 732      1557  D2    2011  2012-03-16   Aachen        Union Berlin     1
# 785      1138  D2    2011  2012-03-30   Aachen             Dresden     0
# 861      1348  D2    2011  2012-04-11   Aachen              Bochum     2
# 920      1176  D2    2011  2012-04-23   Aachen       Ein Frankfurt     0
# 938      1247  D2    2011  2012-04-29   Aachen           Karlsruhe     1
#
#      FTAG FTR
# 15      2   A
# 46      2   A
# 102     0   D
# 167     0   D
# 206     3   A
# 281     1   H
# 335     2   D
# 418     2   D
# 449     1   D
# 580     1   H
# 640     0   D
# 681     3   A
# 732     3   A
# 785     1   A
# 861     0   H
# 920     3   A
# 938     0   H

# %%
df[df['HomeTeam']== 'Aachen']['FTHG'].sum()
# Out:
# 15

# %% [markdown]
# ## Identify the first and last day of the 2011 season

# %%
c.execute('''select date from Matches where season = 2011 order by date;''').fetchone()
# Out:
# ('2011-07-15',)

# %%
c.execute('''select date from Matches where season = 2011 order by date desc;''').fetchone()
# Out:
# ('2012-05-13',)

# %% [markdown]
# ## Identify the set of teams played in 2011

# %%
hometeam = set(c.execute(
    '''select distinct hometeam from Matches where season = 2011 order by hometeam;''').fetchall())
print(len(hometeam))
hometeam
# Out:
# 56
# {('Aachen',),
#  ('Arsenal',),
#  ('Aston Villa',),
#  ('Augsburg',),
#  ('Bayern Munich',),
#  ('Blackburn',),
#  ('Bochum',),
#  ('Bolton',),
#  ('Braunschweig',),
#  ('Chelsea',),
#  ('Cottbus',),
#  ('Dortmund',),
#  ('Dresden',),
#  ('Duisburg',),
#  ('Ein Frankfurt',),
#  ('Erzgebirge Aue',),
#  ('Everton',),
#  ('FC Koln',),
#  ('Fortuna Dusseldorf',),
#  ('Frankfurt FSV',),
#  ('Freiburg',),
#  ('Fulham',),
#  ('Greuther Furth',),
#  ('Hamburg',),
#  ('Hannover',),
#  ('Hansa Rostock',),
#  ('Hertha',),
#  ('Hoffenheim',),
#  ('Ingolstadt',),
#  ('Kaiserslautern',),
#  ('Karlsruhe',),
#  ('Leverkusen',),
#  ('Liverpool',),
#  ("M'gladbach",),
#  ('Mainz',),
#  ('Man City',),
#  ('Man United',),
#  ('Munich 1860',),
#  ('Newcastle',),
#  ('Norwich',),
#  ('Nurnberg',),
#  ('Paderborn',),
#  ('QPR',),
#  ('Schalke 04',),
#  ('St Pauli',),
#  ('Stoke',),
#  ('Stuttgart',),
#  ('Sunderland',),
#  ('Swansea',),
#  ('Tottenham',),
#  ('Union Berlin',),
#  ('Werder Bremen',),
#  ('West Brom',),
#  ('Wigan',),
#  ('Wolfsburg',),
#  ('Wolves',)}

# %%
awayteam = set(c.execute('''select distinct awayteam from Matches where season = 2011 order by awayteam;''').fetchall())
print(len(awayteam))
awayteam
# Out:
# 56
# {('Aachen',),
#  ('Arsenal',),
#  ('Aston Villa',),
#  ('Augsburg',),
#  ('Bayern Munich',),
#  ('Blackburn',),
#  ('Bochum',),
#  ('Bolton',),
#  ('Braunschweig',),
#  ('Chelsea',),
#  ('Cottbus',),
#  ('Dortmund',),
#  ('Dresden',),
#  ('Duisburg',),
#  ('Ein Frankfurt',),
#  ('Erzgebirge Aue',),
#  ('Everton',),
#  ('FC Koln',),
#  ('Fortuna Dusseldorf',),
#  ('Frankfurt FSV',),
#  ('Freiburg',),
#  ('Fulham',),
#  ('Greuther Furth',),
#  ('Hamburg',),
#  ('Hannover',),
#  ('Hansa Rostock',),
#  ('Hertha',),
#  ('Hoffenheim',),
#  ('Ingolstadt',),
#  ('Kaiserslautern',),
#  ('Karlsruhe',),
#  ('Leverkusen',),
#  ('Liverpool',),
#  ("M'gladbach",),
#  ('Mainz',),
#  ('Man City',),
#  ('Man United',),
#  ('Munich 1860',),
#  ('Newcastle',),
#  ('Norwich',),
#  ('Nurnberg',),
#  ('Paderborn',),
#  ('QPR',),
#  ('Schalke 04',),
#  ('St Pauli',),
#  ('Stoke',),
#  ('Stuttgart',),
#  ('Sunderland',),
#  ('Swansea',),
#  ('Tottenham',),
#  ('Union Berlin',),
#  ('Werder Bremen',),
#  ('West Brom',),
#  ('Wigan',),
#  ('Wolfsburg',),
#  ('Wolves',)}

# %%
hometeam - awayteam
# Out:
# set()

# %% [markdown]
# ### Clean special characters

# %%
team = c.execute(
    '''select distinct hometeam from Matches where season = 2011 order by hometeam;''').fetchall()
print(len(team))
team
# Out:
# 56
# [('Aachen',),
#  ('Arsenal',),
#  ('Aston Villa',),
#  ('Augsburg',),
#  ('Bayern Munich',),
#  ('Blackburn',),
#  ('Bochum',),
#  ('Bolton',),
#  ('Braunschweig',),
#  ('Chelsea',),
#  ('Cottbus',),
#  ('Dortmund',),
#  ('Dresden',),
#  ('Duisburg',),
#  ('Ein Frankfurt',),
#  ('Erzgebirge Aue',),
#  ('Everton',),
#  ('FC Koln',),
#  ('Fortuna Dusseldorf',),
#  ('Frankfurt FSV',),
#  ('Freiburg',),
#  ('Fulham',),
#  ('Greuther Furth',),
#  ('Hamburg',),
#  ('Hannover',),
#  ('Hansa Rostock',),
#  ('Hertha',),
#  ('Hoffenheim',),
#  ('Ingolstadt',),
#  ('Kaiserslautern',),
#  ('Karlsruhe',),
#  ('Leverkusen',),
#  ('Liverpool',),
#  ("M'gladbach",),
#  ('Mainz',),
#  ('Man City',),
#  ('Man United',),
#  ('Munich 1860',),
#  ('Newcastle',),
#  ('Norwich',),
#  ('Nurnberg',),
#  ('Paderborn',),
#  ('QPR',),
#  ('Schalke 04',),
#  ('St Pauli',),
#  ('Stoke',),
#  ('Stuttgart',),
#  ('Sunderland',),
#  ('Swansea',),
#  ('Tottenham',),
#  ('Union Berlin',),
#  ('Werder Bremen',),
#  ('West Brom',),
#  ('Wigan',),
#  ('Wolfsburg',),
#  ('Wolves',)]

# %%
teams = []
for t in team:
    newt = t[0].translate({ord(i): ''''{}'''.format(i) for i in "'"})
    teams.append(newt)
teams
# hteam[0]
# Out:
# ['Aachen',
#  'Arsenal',
#  'Aston Villa',
#  'Augsburg',
#  'Bayern Munich',
#  'Blackburn',
#  'Bochum',
#  'Bolton',
#  'Braunschweig',
#  'Chelsea',
#  'Cottbus',
#  'Dortmund',
#  'Dresden',
#  'Duisburg',
#  'Ein Frankfurt',
#  'Erzgebirge Aue',
#  'Everton',
#  'FC Koln',
#  'Fortuna Dusseldorf',
#  'Frankfurt FSV',
#  'Freiburg',
#  'Fulham',
#  'Greuther Furth',
#  'Hamburg',
#  'Hannover',
#  'Hansa Rostock',
#  'Hertha',
#  'Hoffenheim',
#  'Ingolstadt',
#  'Kaiserslautern',
#  'Karlsruhe',
#  'Leverkusen',
#  'Liverpool',
#  "M''gladbach",
#  'Mainz',
#  'Man City',
#  'Man United',
#  'Munich 1860',
#  'Newcastle',
#  'Norwich',
#  'Nurnberg',
#  'Paderborn',
#  'QPR',
#  'Schalke 04',
#  'St Pauli',
#  'Stoke',
#  'Stuttgart',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'Union Berlin',
#  'Werder Bremen',
#  'West Brom',
#  'Wigan',
#  'Wolfsburg',
#  'Wolves']

# %% [markdown]
# ## #1&2 Sum team goals

# %%
c.execute('''select FTHG from Matches where season = 2011 and hometeam = 'Aachen';''').fetchall()
# Out:
# [(0,),
#  (2,),
#  (0,),
#  (1,),
#  (2,),
#  (0,),
#  (2,),
#  (2,),
#  (0,),
#  (0,),
#  (1,),
#  (0,),
#  (1,),
#  (0,),
#  (1,),
#  (3,),
#  (0,)]

# %%
c.execute('''select sum(FTHG) from Matches where season = 2011 and hometeam = 'Aachen';''').fetchall()
# Out:
# [(15,)]

# %%
hg=[]
for t in teams:
    q = '''select sum(FTHG) from Matches where season = 2011 and hometeam = '{}';'''.format(t)
    hg.append(c.execute(q).fetchall()[0][0])
hg
# Out:
# [15,
#  39,
#  20,
#  20,
#  49,
#  26,
#  23,
#  23,
#  21,
#  41,
#  18,
#  44,
#  30,
#  23,
#  38,
#  19,
#  28,
#  20,
#  35,
#  20,
#  24,
#  36,
#  46,
#  19,
#  31,
#  20,
#  19,
#  21,
#  28,
#  12,
#  23,
#  28,
#  24,
#  29,
#  27,
#  55,
#  52,
#  35,
#  29,
#  28,
#  22,
#  28,
#  24,
#  47,
#  36,
#  25,
#  36,
#  26,
#  27,
#  39,
#  30,
#  31,
#  21,
#  22,
#  29,
#  19]

# %%
ag=[]
for t in teams:
    q = '''select sum(FTAG) from Matches where season = 2011 and awayteam = '{}';'''.format(t)
    ag.append(c.execute(q).fetchall()[0][0])
ag
# Out:
# [15,
#  35,
#  17,
#  16,
#  28,
#  22,
#  18,
#  23,
#  16,
#  24,
#  12,
#  36,
#  20,
#  19,
#  38,
#  12,
#  22,
#  19,
#  29,
#  23,
#  21,
#  12,
#  27,
#  16,
#  10,
#  14,
#  19,
#  20,
#  15,
#  12,
#  11,
#  24,
#  23,
#  20,
#  20,
#  38,
#  37,
#  27,
#  27,
#  24,
#  16,
#  23,
#  19,
#  27,
#  23,
#  11,
#  27,
#  19,
#  17,
#  27,
#  25,
#  18,
#  24,
#  20,
#  18,
#  21]

# %% [markdown]
# ## #3 Sum team wins

# %%
c.execute('''select count(FTR) from Matches where season = 2011 and hometeam = 'Aachen' and FTR = 'H';''').fetchall()
# Out:
# [(4,)]

# %%
hw=[]
for t in teams:
    q = '''select count(FTR) from Matches where season = 2011 and hometeam = '{}' and FTR = 'H';'''.format(t)
    hw.append(c.execute(q).fetchall()[0][0])
hw
# Out:
# [4,
#  12,
#  4,
#  6,
#  14,
#  6,
#  7,
#  4,
#  6,
#  12,
#  4,
#  14,
#  8,
#  8,
#  11,
#  5,
#  10,
#  5,
#  11,
#  3,
#  6,
#  10,
#  14,
#  3,
#  10,
#  3,
#  4,
#  4,
#  6,
#  2,
#  8,
#  8,
#  6,
#  9,
#  7,
#  18,
#  15,
#  10,
#  11,
#  7,
#  6,
#  9,
#  7,
#  13,
#  12,
#  7,
#  10,
#  7,
#  8,
#  13,
#  11,
#  8,
#  6,
#  5,
#  10,
#  3]

# %%
aw=[]
for t in teams:
    q = '''select count(FTR) from Matches where season = 2011 and awayteam = '{}' and FTR = 'A';'''.format(t)
    aw.append(c.execute(q).fetchall()[0][0])
aw
# Out:
# [2,
#  9,
#  3,
#  2,
#  9,
#  2,
#  3,
#  6,
#  4,
#  6,
#  4,
#  11,
#  4,
#  2,
#  9,
#  3,
#  5,
#  3,
#  5,
#  4,
#  4,
#  4,
#  6,
#  5,
#  2,
#  2,
#  3,
#  6,
#  2,
#  2,
#  1,
#  7,
#  8,
#  8,
#  2,
#  10,
#  13,
#  7,
#  8,
#  5,
#  6,
#  8,
#  3,
#  7,
#  6,
#  4,
#  5,
#  4,
#  4,
#  7,
#  3,
#  3,
#  7,
#  6,
#  3,
#  2]

# %% [markdown]
# ## #4a Sum team losses

# %%
hl=[]
for t in teams:
    q = '''select count(FTR) from Matches where season = 2011 and hometeam = '{}' and FTR = 'A';'''.format(t)
    hl.append(c.execute(q).fetchall()[0][0])
hl
# Out:
# [7,
#  3,
#  8,
#  4,
#  2,
#  12,
#  7,
#  11,
#  3,
#  4,
#  5,
#  1,
#  4,
#  7,
#  1,
#  5,
#  6,
#  8,
#  1,
#  4,
#  5,
#  4,
#  2,
#  7,
#  0,
#  7,
#  10,
#  4,
#  3,
#  10,
#  6,
#  5,
#  4,
#  1,
#  7,
#  0,
#  2,
#  5,
#  3,
#  6,
#  7,
#  2,
#  7,
#  3,
#  2,
#  4,
#  4,
#  5,
#  4,
#  3,
#  4,
#  5,
#  10,
#  7,
#  5,
#  13]

# %%
al=[]
for t in teams:
    q = '''select count(FTR) from Matches where season = 2011 and awayteam = '{}' and FTR = 'H';'''.format(t)
    al.append(c.execute(q).fetchall()[0][0])
al
# Out:
# [8,
#  7,
#  6,
#  8,
#  5,
#  11,
#  10,
#  11,
#  6,
#  6,
#  10,
#  2,
#  9,
#  8,
#  5,
#  10,
#  6,
#  12,
#  3,
#  9,
#  9,
#  10,
#  2,
#  7,
#  10,
#  10,
#  7,
#  9,
#  10,
#  9,
#  13,
#  5,
#  10,
#  7,
#  6,
#  5,
#  3,
#  6,
#  8,
#  9,
#  9,
#  5,
#  14,
#  7,
#  6,
#  11,
#  7,
#  10,
#  11,
#  6,
#  10,
#  9,
#  7,
#  10,
#  11,
#  10]

# %% [markdown]
# ## #4b Save results in new table and histogram

# %%
teams
# Out:
# ['Aachen',
#  'Arsenal',
#  'Aston Villa',
#  'Augsburg',
#  'Bayern Munich',
#  'Blackburn',
#  'Bochum',
#  'Bolton',
#  'Braunschweig',
#  'Chelsea',
#  'Cottbus',
#  'Dortmund',
#  'Dresden',
#  'Duisburg',
#  'Ein Frankfurt',
#  'Erzgebirge Aue',
#  'Everton',
#  'FC Koln',
#  'Fortuna Dusseldorf',
#  'Frankfurt FSV',
#  'Freiburg',
#  'Fulham',
#  'Greuther Furth',
#  'Hamburg',
#  'Hannover',
#  'Hansa Rostock',
#  'Hertha',
#  'Hoffenheim',
#  'Ingolstadt',
#  'Kaiserslautern',
#  'Karlsruhe',
#  'Leverkusen',
#  'Liverpool',
#  "M''gladbach",
#  'Mainz',
#  'Man City',
#  'Man United',
#  'Munich 1860',
#  'Newcastle',
#  'Norwich',
#  'Nurnberg',
#  'Paderborn',
#  'QPR',
#  'Schalke 04',
#  'St Pauli',
#  'Stoke',
#  'Stuttgart',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'Union Berlin',
#  'Werder Bremen',
#  'West Brom',
#  'Wigan',
#  'Wolfsburg',
#  'Wolves']

# %%
type(hg[1])
# Out:
# int

# %%
c.execute('''create table results (
                                 id INTEGER PRIMARY KEY,
                                 teamnames text, 
                                 homegoals integer, 
                                 awaygoals integer, 
                                 homewins integer, 
                                 awaywins integer, 
                                 homelosses integer,
                                 awaylosses integer
                                 );''')

# %%
c.execute('''drop table results;''')

# %%
for i in teams:
    c.execute('''insert into results (teamnames) values ('{}');'''.format(i)).fetchall()

# %%
for i,j,k,l,m,n in hg,ag,hw,aw,hl,al:
    c.execute('''insert into results (homegoals) values ('{}');'''.format(i)).fetchall()

# %%
c.execute('''insert into results (homegoals) values ('15');''')

# %%
value = []
for i in range(0,len(hl)):
    value.append([teams[i],hg[i],ag[i],hw[i],aw[i],hl[i],al[i]])
value
# Out:
# [['Aachen', 15, 15, 4, 2, 7, 8],
#  ['Arsenal', 39, 35, 12, 9, 3, 7],
#  ['Aston Villa', 20, 17, 4, 3, 8, 6],
#  ['Augsburg', 20, 16, 6, 2, 4, 8],
#  ['Bayern Munich', 49, 28, 14, 9, 2, 5],
#  ['Blackburn', 26, 22, 6, 2, 12, 11],
#  ['Bochum', 23, 18, 7, 3, 7, 10],
#  ['Bolton', 23, 23, 4, 6, 11, 11],
#  ['Braunschweig', 21, 16, 6, 4, 3, 6],
#  ['Chelsea', 41, 24, 12, 6, 4, 6],
#  ['Cottbus', 18, 12, 4, 4, 5, 10],
#  ['Dortmund', 44, 36, 14, 11, 1, 2],
#  ['Dresden', 30, 20, 8, 4, 4, 9],
#  ['Duisburg', 23, 19, 8, 2, 7, 8],
#  ['Ein Frankfurt', 38, 38, 11, 9, 1, 5],
#  ['Erzgebirge Aue', 19, 12, 5, 3, 5, 10],
#  ['Everton', 28, 22, 10, 5, 6, 6],
#  ['FC Koln', 20, 19, 5, 3, 8, 12],
#  ['Fortuna Dusseldorf', 35, 29, 11, 5, 1, 3],
#  ['Frankfurt FSV', 20, 23, 3, 4, 4, 9],
#  ['Freiburg', 24, 21, 6, 4, 5, 9],
#  ['Fulham', 36, 12, 10, 4, 4, 10],
#  ['Greuther Furth', 46, 27, 14, 6, 2, 2],
#  ['Hamburg', 19, 16, 3, 5, 7, 7],
#  ['Hannover', 31, 10, 10, 2, 0, 10],
#  ['Hansa Rostock', 20, 14, 3, 2, 7, 10],
#  ['Hertha', 19, 19, 4, 3, 10, 7],
#  ['Hoffenheim', 21, 20, 4, 6, 4, 9],
#  ['Ingolstadt', 28, 15, 6, 2, 3, 10],
#  ['Kaiserslautern', 12, 12, 2, 2, 10, 9],
#  ['Karlsruhe', 23, 11, 8, 1, 6, 13],
#  ['Leverkusen', 28, 24, 8, 7, 5, 5],
#  ['Liverpool', 24, 23, 6, 8, 4, 10],
#  ["M''gladbach", 29, 20, 9, 8, 1, 7],
#  ['Mainz', 27, 20, 7, 2, 7, 6],
#  ['Man City', 55, 38, 18, 10, 0, 5],
#  ['Man United', 52, 37, 15, 13, 2, 3],
#  ['Munich 1860', 35, 27, 10, 7, 5, 6],
#  ['Newcastle', 29, 27, 11, 8, 3, 8],
#  ['Norwich', 28, 24, 7, 5, 6, 9],
#  ['Nurnberg', 22, 16, 6, 6, 7, 9],
#  ['Paderborn', 28, 23, 9, 8, 2, 5],
#  ['QPR', 24, 19, 7, 3, 7, 14],
#  ['Schalke 04', 47, 27, 13, 7, 3, 7],
#  ['St Pauli', 36, 23, 12, 6, 2, 6],
#  ['Stoke', 25, 11, 7, 4, 4, 11],
#  ['Stuttgart', 36, 27, 10, 5, 4, 7],
#  ['Sunderland', 26, 19, 7, 4, 5, 10],
#  ['Swansea', 27, 17, 8, 4, 4, 11],
#  ['Tottenham', 39, 27, 13, 7, 3, 6],
#  ['Union Berlin', 30, 25, 11, 3, 4, 10],
#  ['Werder Bremen', 31, 18, 8, 3, 5, 9],
#  ['West Brom', 21, 24, 6, 7, 10, 7],
#  ['Wigan', 22, 20, 5, 6, 7, 10],
#  ['Wolfsburg', 29, 18, 10, 3, 5, 11],
#  ['Wolves', 19, 21, 3, 2, 13, 10]]

# %%
for i in value:
    q = '''insert into results ( teamnames,
                                 homegoals , 
                                 awaygoals, 
                                 homewins , 
                                 awaywins , 
                                 homelosses ,
                                 awaylosses) values (?,?,?,?,?,?,?);'''
    c.execute(q, i)

# %%
c.execute('''select * from results;''').fetchall()
# Out:
# [(1, 'Aachen', 15, 15, 4, 2, 7, 8),
#  (2, 'Arsenal', 39, 35, 12, 9, 3, 7),
#  (3, 'Aston Villa', 20, 17, 4, 3, 8, 6),
#  (4, 'Augsburg', 20, 16, 6, 2, 4, 8),
#  (5, 'Bayern Munich', 49, 28, 14, 9, 2, 5),
#  (6, 'Blackburn', 26, 22, 6, 2, 12, 11),
#  (7, 'Bochum', 23, 18, 7, 3, 7, 10),
#  (8, 'Bolton', 23, 23, 4, 6, 11, 11),
#  (9, 'Braunschweig', 21, 16, 6, 4, 3, 6),
#  (10, 'Chelsea', 41, 24, 12, 6, 4, 6),
#  (11, 'Cottbus', 18, 12, 4, 4, 5, 10),
#  (12, 'Dortmund', 44, 36, 14, 11, 1, 2),
#  (13, 'Dresden', 30, 20, 8, 4, 4, 9),
#  (14, 'Duisburg', 23, 19, 8, 2, 7, 8),
#  (15, 'Ein Frankfurt', 38, 38, 11, 9, 1, 5),
#  (16, 'Erzgebirge Aue', 19, 12, 5, 3, 5, 10),
#  (17, 'Everton', 28, 22, 10, 5, 6, 6),
#  (18, 'FC Koln', 20, 19, 5, 3, 8, 12),
#  (19, 'Fortuna Dusseldorf', 35, 29, 11, 5, 1, 3),
#  (20, 'Frankfurt FSV', 20, 23, 3, 4, 4, 9),
#  (21, 'Freiburg', 24, 21, 6, 4, 5, 9),
#  (22, 'Fulham', 36, 12, 10, 4, 4, 10),
#  (23, 'Greuther Furth', 46, 27, 14, 6, 2, 2),
#  (24, 'Hamburg', 19, 16, 3, 5, 7, 7),
#  (25, 'Hannover', 31, 10, 10, 2, 0, 10),
#  (26, 'Hansa Rostock', 20, 14, 3, 2, 7, 10),
#  (27, 'Hertha', 19, 19, 4, 3, 10, 7),
#  (28, 'Hoffenheim', 21, 20, 4, 6, 4, 9),
#  (29, 'Ingolstadt', 28, 15, 6, 2, 3, 10),
#  (30, 'Kaiserslautern', 12, 12, 2, 2, 10, 9),
#  (31, 'Karlsruhe', 23, 11, 8, 1, 6, 13),
#  (32, 'Leverkusen', 28, 24, 8, 7, 5, 5),
#  (33, 'Liverpool', 24, 23, 6, 8, 4, 10),
#  (34, "M''gladbach", 29, 20, 9, 8, 1, 7),
#  (35, 'Mainz', 27, 20, 7, 2, 7, 6),
#  (36, 'Man City', 55, 38, 18, 10, 0, 5),
#  (37, 'Man United', 52, 37, 15, 13, 2, 3),
#  (38, 'Munich 1860', 35, 27, 10, 7, 5, 6),
#  (39, 'Newcastle', 29, 27, 11, 8, 3, 8),
#  (40, 'Norwich', 28, 24, 7, 5, 6, 9),
#  (41, 'Nurnberg', 22, 16, 6, 6, 7, 9),
#  (42, 'Paderborn', 28, 23, 9, 8, 2, 5),
#  (43, 'QPR', 24, 19, 7, 3, 7, 14),
#  (44, 'Schalke 04', 47, 27, 13, 7, 3, 7),
#  (45, 'St Pauli', 36, 23, 12, 6, 2, 6),
#  (46, 'Stoke', 25, 11, 7, 4, 4, 11),
#  (47, 'Stuttgart', 36, 27, 10, 5, 4, 7),
#  (48, 'Sunderland', 26, 19, 7, 4, 5, 10),
#  (49, 'Swansea', 27, 17, 8, 4, 4, 11),
#  (50, 'Tottenham', 39, 27, 13, 7, 3, 6),
#  (51, 'Union Berlin', 30, 25, 11, 3, 4, 10),
#  (52, 'Werder Bremen', 31, 18, 8, 3, 5, 9),
#  (53, 'West Brom', 21, 24, 6, 7, 10, 7),
#  (54, 'Wigan', 22, 20, 5, 6, 7, 10),
#  (55, 'Wolfsburg', 29, 18, 10, 3, 5, 11),
#  (56, 'Wolves', 19, 21, 3, 2, 13, 10)]

# %%
conn.commit()

# %%
c.description
# Out:
# (('id', None, None, None, None, None, None),
#  ('teamnames', None, None, None, None, None, None),
#  ('homegoals', None, None, None, None, None, None),
#  ('awaygoals', None, None, None, None, None, None),
#  ('homewins', None, None, None, None, None, None),
#  ('awaywins', None, None, None, None, None, None),
#  ('homelosses', None, None, None, None, None, None),
#  ('awaylosses', None, None, None, None, None, None))

# %%
c.execute('''select * from results;''')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     id           teamnames  homegoals  awaygoals  homewins  awaywins  \
# 0    1              Aachen         15         15         4         2
# 1    2             Arsenal         39         35        12         9
# 2    3         Aston Villa         20         17         4         3
# 3    4            Augsburg         20         16         6         2
# 4    5       Bayern Munich         49         28        14         9
# 5    6           Blackburn         26         22         6         2
# 6    7              Bochum         23         18         7         3
# 7    8              Bolton         23         23         4         6
# 8    9        Braunschweig         21         16         6         4
# 9   10             Chelsea         41         24        12         6
# 10  11             Cottbus         18         12         4         4
# 11  12            Dortmund         44         36        14        11
# 12  13             Dresden         30         20         8         4
# 13  14            Duisburg         23         19         8         2
# 14  15       Ein Frankfurt         38         38        11         9
# 15  16      Erzgebirge Aue         19         12         5         3
# 16  17             Everton         28         22        10         5
# 17  18             FC Koln         20         19         5         3
# 18  19  Fortuna Dusseldorf         35         29        11         5
# 19  20       Frankfurt FSV         20         23         3         4
# 20  21            Freiburg         24         21         6         4
# 21  22              Fulham         36         12        10         4
# 22  23      Greuther Furth         46         27        14         6
# 23  24             Hamburg         19         16         3         5
# 24  25            Hannover         31         10        10         2
# 25  26       Hansa Rostock         20         14         3         2
# 26  27              Hertha         19         19         4         3
# 27  28          Hoffenheim         21         20         4         6
# 28  29          Ingolstadt         28         15         6         2
# 29  30      Kaiserslautern         12         12         2         2
# 30  31           Karlsruhe         23         11         8         1
# 31  32          Leverkusen         28         24         8         7
# 32  33           Liverpool         24         23         6         8
# 33  34         M''gladbach         29         20         9         8
# 34  35               Mainz         27         20         7         2
# 35  36            Man City         55         38        18        10
# 36  37          Man United         52         37        15        13
# 37  38         Munich 1860         35         27        10         7
# 38  39           Newcastle         29         27        11         8
# 39  40             Norwich         28         24         7         5
# 40  41            Nurnberg         22         16         6         6
# 41  42           Paderborn         28         23         9         8
# 42  43                 QPR         24         19         7         3
# 43  44          Schalke 04         47         27        13         7
# 44  45            St Pauli         36         23        12         6
# 45  46               Stoke         25         11         7         4
# 46  47           Stuttgart         36         27        10         5
# 47  48          Sunderland         26         19         7         4
# 48  49             Swansea         27         17         8         4
# 49  50           Tottenham         39         27        13         7
# 50  51        Union Berlin         30         25        11         3
# 51  52       Werder Bremen         31         18         8         3
# 52  53           West Brom         21         24         6         7
# 53  54               Wigan         22         20         5         6
# 54  55           Wolfsburg         29         18        10         3
# 55  56              Wolves         19         21         3         2
#
#     homelosses  awaylosses
# 0            7           8
# 1            3           7
# 2            8           6
# 3            4           8
# 4            2           5
# 5           12          11
# 6            7          10
# 7           11          11
# 8            3           6
# 9            4           6
# 10           5          10
# 11           1           2
# 12           4           9
# 13           7           8
# 14           1           5
# 15           5          10
# 16           6           6
# 17           8          12
# 18           1           3
# 19           4           9
# 20           5           9
# 21           4          10
# 22           2           2
# 23           7           7
# 24           0          10
# 25           7          10
# 26          10           7
# 27           4           9
# 28           3          10
# 29          10           9
# 30           6          13
# 31           5           5
# 32           4          10
# 33           1           7
# 34           7           6
# 35           0           5
# 36           2           3
# 37           5           6
# 38           3           8
# 39           6           9
# 40           7           9
# 41           2           5
# 42           7          14
# 43           3           7
# 44           2           6
# 45           4          11
# 46           4           7
# 47           5          10
# 48           4          11
# 49           3           6
# 50           4          10
# 51           5           9
# 52          10           7
# 53           7          10
# 54           5          11
# 55          13          10

# %%
df['totalgoals']=df.homegoals + df.awaygoals
df['totalwins']=df.homewins + df.awaywins
df['totalloss']=df.homelosses + df.awaylosses

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1)
sns.distplot(df['totalwins'] , color="skyblue", label="High",)
sns.distplot(df['totalloss'] , color="red", label="Low",)

ax.legend(['Total Team Wins', 'Total Team Losses'])

ax.set(xlim=(0, 40))
ax.set_xlabel('Total Team Wins and Losses')
ax.set_ylabel('Count')
#plt.legend(fontsize='medium', title_fontsize='20')
plt.title('Density Distribution of Total Team Wins and Total Team Losses in 2011')

# plt.show()
# Out:
# Text(0.5, 1.0, 'Density Distribution of Total Team Wins and Total Team Losses in 2011')

# %% [markdown]
# ## Getting the Weather Data
# Note that for this last calculation, you'll need to figure out if it was raining or not during the game. The database itself does not contain this information, but it does contain the date on which the game was played. For this, you'll need to use the DarkSky API to get the historical weather data for that day. Note that each game is played in a different location, and this information is not contained in our SQL database. However, the teams in this database are largely german, so go ahead and just use the weather in Berlin, Germany as a proxy for this information. If it was raining in Berlin on the day the game was played, count that as rain game--you do not need to try and figure out the actual weather at each game's location, because we don't have that information!

# %% [markdown]
# - 5. The team's win percentage on days where it was raining during games in the 2011 season.

# %%
dfdate = pd.DataFrame(dfd.Date.unique())

# %%
dfdate.columns = ["Date"]

# %%
dfdate.head()
# Out:
#          Date
# 0  2011-07-15
# 1  2011-07-16
# 2  2011-07-17
# 3  2011-07-18
# 4  2011-07-22

# %%
import datetime
import time
import os


class WeatherGetter():

    def __init__(self, key_file, long, lat, datestring):
        self.api_key = os.environ[key_file]
        self.url_base = 'https://api.darksky.net/forecast/'
        self.long = long
        self.lat = lat
        self.dfd = datestring

    def get_unix(self, dateCol="Date"):
        # mktime assumes local time zone at 12am, germany is 6 hours ahead so it will be same day (6AM german time)
        self.dfd['unix_date'] = self.dfd[dateCol].apply(lambda s: str(
            round(time.mktime(datetime.datetime.strptime(s, "%Y-%m-%d").timetuple()))))
        return self.dfd

    def get_API(self):
        self.dfdapi = self.dfd.copy()
        self.dfdapi['url'] = self.url_base + self.api_key + '/' + \
            self.long + ',' + self.lat + ',' + self.dfdapi['unix_date']
        return self.dfdapi

    def get_rain(self):
        rain = []
        for element in self.dfdapi['url']:
            response = requests.get(element)
#           if response.status_code != 200:
#               return response.status_code
            soup = BeautifulSoup(response.text)
            par1 = soup.find_all('p')  # return back list
            par2 = par1[0]  # soup object inside list
            par3 = par2.contents[0]  # contents convert soup to text
            raini = json.loads(par3)
            rain.append(raini['daily']['data'][0]['precipIntensity'])
        self.dfd['Rain'] = rain
        return self.dfd

# %%
Berlin2011 = WeatherGetter("WEATHER_KEY", '52.5200', '13.4050', dfdate)

# %%
print(Berlin2011.api_key)
print(Berlin2011.url_base)
print(Berlin2011.long)
print(Berlin2011.lat)
print(Berlin2011.dfd)
# Out:
# cd35acf369b55daae38db9a2dd08b546
# https://api.darksky.net/forecast/
# 52.5200
# 13.4050
#            Date
# 0    2011-07-15
# 1    2011-07-16
# 2    2011-07-17
# 3    2011-07-18
# 4    2011-07-22
# 5    2011-07-23
# 6    2011-07-24
# 7    2011-07-25
# 8    2011-08-05
# 9    2011-08-06
# 10   2011-08-07
# 11   2011-08-08
# 12   2011-08-12
# 13   2011-08-13
# 14   2011-08-14
# 15   2011-08-15
# 16   2011-08-19
# 17   2011-08-20
# 18   2011-08-21
# 19   2011-08-22
# 20   2011-08-26
# 21   2011-08-27
# 22   2011-08-28
# 23   2011-08-29
# 24   2011-09-09
# 25   2011-09-10
# 26   2011-09-11
# 27   2011-09-12
# 28   2011-09-16
# 29   2011-09-17
# ..          ...
# 135  2012-03-30
# 136  2012-03-31
# 137  2012-04-01
# 138  2012-04-02
# 139  2012-04-05
# 140  2012-04-06
# 141  2012-04-07
# 142  2012-04-08
# 143  2012-04-09
# 144  2012-04-10
# 145  2012-04-11
# 146  2012-04-13
# 147  2012-04-14
# 148  2012-04-15
# 149  2012-04-16
# 150  2012-04-20
# 151  2012-04-21
# 152  2012-04-22
# 153  2012-04-23
# 154  2012-04-24
# 155  2012-04-28
# 156  2012-04-29
# 157  2012-04-30
# 158  2012-05-01
# 159  2012-05-02
# 160  2012-05-05
# 161  2012-05-06
# 162  2012-05-07
# 163  2012-05-08
# 164  2012-05-13
#
# [165 rows x 1 columns]

# %%
Berlin2011.get_unix("Date")
# Out:
#            Date   unix_date
# 0    2011-07-15  1310702400
# 1    2011-07-16  1310788800
# 2    2011-07-17  1310875200
# 3    2011-07-18  1310961600
# 4    2011-07-22  1311307200
# 5    2011-07-23  1311393600
# 6    2011-07-24  1311480000
# 7    2011-07-25  1311566400
# 8    2011-08-05  1312516800
# 9    2011-08-06  1312603200
# 10   2011-08-07  1312689600
# 11   2011-08-08  1312776000
# 12   2011-08-12  1313121600
# 13   2011-08-13  1313208000
# 14   2011-08-14  1313294400
# 15   2011-08-15  1313380800
# 16   2011-08-19  1313726400
# 17   2011-08-20  1313812800
# 18   2011-08-21  1313899200
# 19   2011-08-22  1313985600
# 20   2011-08-26  1314331200
# 21   2011-08-27  1314417600
# 22   2011-08-28  1314504000
# 23   2011-08-29  1314590400
# 24   2011-09-09  1315540800
# 25   2011-09-10  1315627200
# 26   2011-09-11  1315713600
# 27   2011-09-12  1315800000
# 28   2011-09-16  1316145600
# 29   2011-09-17  1316232000
# ..          ...         ...
# 135  2012-03-30  1333080000
# 136  2012-03-31  1333166400
# 137  2012-04-01  1333252800
# 138  2012-04-02  1333339200
# 139  2012-04-05  1333598400
# 140  2012-04-06  1333684800
# 141  2012-04-07  1333771200
# 142  2012-04-08  1333857600
# 143  2012-04-09  1333944000
# 144  2012-04-10  1334030400
# 145  2012-04-11  1334116800
# 146  2012-04-13  1334289600
# 147  2012-04-14  1334376000
# 148  2012-04-15  1334462400
# 149  2012-04-16  1334548800
# 150  2012-04-20  1334894400
# 151  2012-04-21  1334980800
# 152  2012-04-22  1335067200
# 153  2012-04-23  1335153600
# 154  2012-04-24  1335240000
# 155  2012-04-28  1335585600
# 156  2012-04-29  1335672000
# 157  2012-04-30  1335758400
# 158  2012-05-01  1335844800
# 159  2012-05-02  1335931200
# 160  2012-05-05  1336190400
# 161  2012-05-06  1336276800
# 162  2012-05-07  1336363200
# 163  2012-05-08  1336449600
# 164  2012-05-13  1336881600
#
# [165 rows x 2 columns]

# %%
dfdate
# Out:
#            Date   unix_date
# 0    2011-07-15  1310702400
# 1    2011-07-16  1310788800
# 2    2011-07-17  1310875200
# 3    2011-07-18  1310961600
# 4    2011-07-22  1311307200
# 5    2011-07-23  1311393600
# 6    2011-07-24  1311480000
# 7    2011-07-25  1311566400
# 8    2011-08-05  1312516800
# 9    2011-08-06  1312603200
# 10   2011-08-07  1312689600
# 11   2011-08-08  1312776000
# 12   2011-08-12  1313121600
# 13   2011-08-13  1313208000
# 14   2011-08-14  1313294400
# 15   2011-08-15  1313380800
# 16   2011-08-19  1313726400
# 17   2011-08-20  1313812800
# 18   2011-08-21  1313899200
# 19   2011-08-22  1313985600
# 20   2011-08-26  1314331200
# 21   2011-08-27  1314417600
# 22   2011-08-28  1314504000
# 23   2011-08-29  1314590400
# 24   2011-09-09  1315540800
# 25   2011-09-10  1315627200
# 26   2011-09-11  1315713600
# 27   2011-09-12  1315800000
# 28   2011-09-16  1316145600
# 29   2011-09-17  1316232000
# ..          ...         ...
# 135  2012-03-30  1333080000
# 136  2012-03-31  1333166400
# 137  2012-04-01  1333252800
# 138  2012-04-02  1333339200
# 139  2012-04-05  1333598400
# 140  2012-04-06  1333684800
# 141  2012-04-07  1333771200
# 142  2012-04-08  1333857600
# 143  2012-04-09  1333944000
# 144  2012-04-10  1334030400
# 145  2012-04-11  1334116800
# 146  2012-04-13  1334289600
# 147  2012-04-14  1334376000
# 148  2012-04-15  1334462400
# 149  2012-04-16  1334548800
# 150  2012-04-20  1334894400
# 151  2012-04-21  1334980800
# 152  2012-04-22  1335067200
# 153  2012-04-23  1335153600
# 154  2012-04-24  1335240000
# 155  2012-04-28  1335585600
# 156  2012-04-29  1335672000
# 157  2012-04-30  1335758400
# 158  2012-05-01  1335844800
# 159  2012-05-02  1335931200
# 160  2012-05-05  1336190400
# 161  2012-05-06  1336276800
# 162  2012-05-07  1336363200
# 163  2012-05-08  1336449600
# 164  2012-05-13  1336881600
#
# [165 rows x 2 columns]

# %%
Berlin2011.get_API()
# Out:
#            Date   unix_date                                                url
# 0    2011-07-15  1310702400  https://api.darksky.net/forecast/cd35acf369b55...
# 1    2011-07-16  1310788800  https://api.darksky.net/forecast/cd35acf369b55...
# 2    2011-07-17  1310875200  https://api.darksky.net/forecast/cd35acf369b55...
# 3    2011-07-18  1310961600  https://api.darksky.net/forecast/cd35acf369b55...
# 4    2011-07-22  1311307200  https://api.darksky.net/forecast/cd35acf369b55...
# 5    2011-07-23  1311393600  https://api.darksky.net/forecast/cd35acf369b55...
# 6    2011-07-24  1311480000  https://api.darksky.net/forecast/cd35acf369b55...
# 7    2011-07-25  1311566400  https://api.darksky.net/forecast/cd35acf369b55...
# 8    2011-08-05  1312516800  https://api.darksky.net/forecast/cd35acf369b55...
# 9    2011-08-06  1312603200  https://api.darksky.net/forecast/cd35acf369b55...
# 10   2011-08-07  1312689600  https://api.darksky.net/forecast/cd35acf369b55...
# 11   2011-08-08  1312776000  https://api.darksky.net/forecast/cd35acf369b55...
# 12   2011-08-12  1313121600  https://api.darksky.net/forecast/cd35acf369b55...
# 13   2011-08-13  1313208000  https://api.darksky.net/forecast/cd35acf369b55...
# 14   2011-08-14  1313294400  https://api.darksky.net/forecast/cd35acf369b55...
# 15   2011-08-15  1313380800  https://api.darksky.net/forecast/cd35acf369b55...
# 16   2011-08-19  1313726400  https://api.darksky.net/forecast/cd35acf369b55...
# 17   2011-08-20  1313812800  https://api.darksky.net/forecast/cd35acf369b55...
# 18   2011-08-21  1313899200  https://api.darksky.net/forecast/cd35acf369b55...
# 19   2011-08-22  1313985600  https://api.darksky.net/forecast/cd35acf369b55...
# 20   2011-08-26  1314331200  https://api.darksky.net/forecast/cd35acf369b55...
# 21   2011-08-27  1314417600  https://api.darksky.net/forecast/cd35acf369b55...
# 22   2011-08-28  1314504000  https://api.darksky.net/forecast/cd35acf369b55...
# 23   2011-08-29  1314590400  https://api.darksky.net/forecast/cd35acf369b55...
# 24   2011-09-09  1315540800  https://api.darksky.net/forecast/cd35acf369b55...
# 25   2011-09-10  1315627200  https://api.darksky.net/forecast/cd35acf369b55...
# 26   2011-09-11  1315713600  https://api.darksky.net/forecast/cd35acf369b55...
# 27   2011-09-12  1315800000  https://api.darksky.net/forecast/cd35acf369b55...
# 28   2011-09-16  1316145600  https://api.darksky.net/forecast/cd35acf369b55...
# 29   2011-09-17  1316232000  https://api.darksky.net/forecast/cd35acf369b55...
# ..          ...         ...                                                ...
# 135  2012-03-30  1333080000  https://api.darksky.net/forecast/cd35acf369b55...
# 136  2012-03-31  1333166400  https://api.darksky.net/forecast/cd35acf369b55...
# 137  2012-04-01  1333252800  https://api.darksky.net/forecast/cd35acf369b55...
# 138  2012-04-02  1333339200  https://api.darksky.net/forecast/cd35acf369b55...
# 139  2012-04-05  1333598400  https://api.darksky.net/forecast/cd35acf369b55...
# 140  2012-04-06  1333684800  https://api.darksky.net/forecast/cd35acf369b55...
# 141  2012-04-07  1333771200  https://api.darksky.net/forecast/cd35acf369b55...
# 142  2012-04-08  1333857600  https://api.darksky.net/forecast/cd35acf369b55...
# 143  2012-04-09  1333944000  https://api.darksky.net/forecast/cd35acf369b55...
# 144  2012-04-10  1334030400  https://api.darksky.net/forecast/cd35acf369b55...
# 145  2012-04-11  1334116800  https://api.darksky.net/forecast/cd35acf369b55...
# 146  2012-04-13  1334289600  https://api.darksky.net/forecast/cd35acf369b55...
# 147  2012-04-14  1334376000  https://api.darksky.net/forecast/cd35acf369b55...
# 148  2012-04-15  1334462400  https://api.darksky.net/forecast/cd35acf369b55...
# 149  2012-04-16  1334548800  https://api.darksky.net/forecast/cd35acf369b55...
# 150  2012-04-20  1334894400  https://api.darksky.net/forecast/cd35acf369b55...
# 151  2012-04-21  1334980800  https://api.darksky.net/forecast/cd35acf369b55...
# 152  2012-04-22  1335067200  https://api.darksky.net/forecast/cd35acf369b55...
# 153  2012-04-23  1335153600  https://api.darksky.net/forecast/cd35acf369b55...
# 154  2012-04-24  1335240000  https://api.darksky.net/forecast/cd35acf369b55...
# 155  2012-04-28  1335585600  https://api.darksky.net/forecast/cd35acf369b55...
# 156  2012-04-29  1335672000  https://api.darksky.net/forecast/cd35acf369b55...
# 157  2012-04-30  1335758400  https://api.darksky.net/forecast/cd35acf369b55...
# 158  2012-05-01  1335844800  https://api.darksky.net/forecast/cd35acf369b55...
# 159  2012-05-02  1335931200  https://api.darksky.net/forecast/cd35acf369b55...
# 160  2012-05-05  1336190400  https://api.darksky.net/forecast/cd35acf369b55...
# 161  2012-05-06  1336276800  https://api.darksky.net/forecast/cd35acf369b55...
# 162  2012-05-07  1336363200  https://api.darksky.net/forecast/cd35acf369b55...
# 163  2012-05-08  1336449600  https://api.darksky.net/forecast/cd35acf369b55...
# 164  2012-05-13  1336881600  https://api.darksky.net/forecast/cd35acf369b55...
#
# [165 rows x 3 columns]

# %%
Berlin2011.get_rain()
# Out:
#            Date   unix_date    Rain
# 0    2011-07-15  1310702400  0.0000
# 1    2011-07-16  1310788800  0.0000
# 2    2011-07-17  1310875200  0.0180
# 3    2011-07-18  1310961600  0.0100
# 4    2011-07-22  1311307200  0.0489
# 5    2011-07-23  1311393600  0.0063
# 6    2011-07-24  1311480000  0.0000
# 7    2011-07-25  1311566400  0.0000
# 8    2011-08-05  1312516800  0.0047
# 9    2011-08-06  1312603200  0.0017
# 10   2011-08-07  1312689600  0.0015
# 11   2011-08-08  1312776000  0.0130
# 12   2011-08-12  1313121600  0.0164
# 13   2011-08-13  1313208000  0.0000
# 14   2011-08-14  1313294400  0.0193
# 15   2011-08-15  1313380800  0.0161
# 16   2011-08-19  1313726400  0.0015
# 17   2011-08-20  1313812800  0.0000
# 18   2011-08-21  1313899200  0.0000
# 19   2011-08-22  1313985600  0.0000
# 20   2011-08-26  1314331200  0.0029
# 21   2011-08-27  1314417600  0.0062
# 22   2011-08-28  1314504000  0.0000
# 23   2011-08-29  1314590400  0.0010
# 24   2011-09-09  1315540800  0.0018
# 25   2011-09-10  1315627200  0.0001
# 26   2011-09-11  1315713600  0.0347
# 27   2011-09-12  1315800000  0.0830
# 28   2011-09-16  1316145600  0.0000
# 29   2011-09-17  1316232000  0.0000
# ..          ...         ...     ...
# 135  2012-03-30  1333080000  0.0000
# 136  2012-03-31  1333166400  0.0003
# 137  2012-04-01  1333252800  0.0000
# 138  2012-04-02  1333339200  0.0001
# 139  2012-04-05  1333598400  0.0000
# 140  2012-04-06  1333684800  0.0000
# 141  2012-04-07  1333771200  0.0000
# 142  2012-04-08  1333857600  0.0000
# 143  2012-04-09  1333944000  0.0000
# 144  2012-04-10  1334030400  0.0000
# 145  2012-04-11  1334116800  0.0000
# 146  2012-04-13  1334289600  0.0000
# 147  2012-04-14  1334376000  0.0000
# 148  2012-04-15  1334462400  0.0000
# 149  2012-04-16  1334548800  0.0000
# 150  2012-04-20  1334894400  0.0000
# 151  2012-04-21  1334980800  0.0000
# 152  2012-04-22  1335067200  0.0000
# 153  2012-04-23  1335153600  0.0000
# 154  2012-04-24  1335240000  0.0039
# 155  2012-04-28  1335585600  0.0000
# 156  2012-04-29  1335672000  0.0000
# 157  2012-04-30  1335758400  0.0000
# 158  2012-05-01  1335844800  0.0000
# 159  2012-05-02  1335931200  0.0000
# 160  2012-05-05  1336190400  0.0003
# 161  2012-05-06  1336276800  0.0035
# 162  2012-05-07  1336363200  0.0000
# 163  2012-05-08  1336449600  0.0000
# 164  2012-05-13  1336881600  0.0000
#
# [165 rows x 3 columns]

# %%
dfdate
# Out:
#            Date   unix_date    Rain
# 0    2011-07-15  1310702400  0.0000
# 1    2011-07-16  1310788800  0.0000
# 2    2011-07-17  1310875200  0.0180
# 3    2011-07-18  1310961600  0.0100
# 4    2011-07-22  1311307200  0.0489
# 5    2011-07-23  1311393600  0.0063
# 6    2011-07-24  1311480000  0.0000
# 7    2011-07-25  1311566400  0.0000
# 8    2011-08-05  1312516800  0.0047
# 9    2011-08-06  1312603200  0.0017
# 10   2011-08-07  1312689600  0.0015
# 11   2011-08-08  1312776000  0.0130
# 12   2011-08-12  1313121600  0.0164
# 13   2011-08-13  1313208000  0.0000
# 14   2011-08-14  1313294400  0.0193
# 15   2011-08-15  1313380800  0.0161
# 16   2011-08-19  1313726400  0.0015
# 17   2011-08-20  1313812800  0.0000
# 18   2011-08-21  1313899200  0.0000
# 19   2011-08-22  1313985600  0.0000
# 20   2011-08-26  1314331200  0.0029
# 21   2011-08-27  1314417600  0.0062
# 22   2011-08-28  1314504000  0.0000
# 23   2011-08-29  1314590400  0.0010
# 24   2011-09-09  1315540800  0.0018
# 25   2011-09-10  1315627200  0.0001
# 26   2011-09-11  1315713600  0.0347
# 27   2011-09-12  1315800000  0.0830
# 28   2011-09-16  1316145600  0.0000
# 29   2011-09-17  1316232000  0.0000
# ..          ...         ...     ...
# 135  2012-03-30  1333080000  0.0000
# 136  2012-03-31  1333166400  0.0003
# 137  2012-04-01  1333252800  0.0000
# 138  2012-04-02  1333339200  0.0001
# 139  2012-04-05  1333598400  0.0000
# 140  2012-04-06  1333684800  0.0000
# 141  2012-04-07  1333771200  0.0000
# 142  2012-04-08  1333857600  0.0000
# 143  2012-04-09  1333944000  0.0000
# 144  2012-04-10  1334030400  0.0000
# 145  2012-04-11  1334116800  0.0000
# 146  2012-04-13  1334289600  0.0000
# 147  2012-04-14  1334376000  0.0000
# 148  2012-04-15  1334462400  0.0000
# 149  2012-04-16  1334548800  0.0000
# 150  2012-04-20  1334894400  0.0000
# 151  2012-04-21  1334980800  0.0000
# 152  2012-04-22  1335067200  0.0000
# 153  2012-04-23  1335153600  0.0000
# 154  2012-04-24  1335240000  0.0039
# 155  2012-04-28  1335585600  0.0000
# 156  2012-04-29  1335672000  0.0000
# 157  2012-04-30  1335758400  0.0000
# 158  2012-05-01  1335844800  0.0000
# 159  2012-05-02  1335931200  0.0000
# 160  2012-05-05  1336190400  0.0003
# 161  2012-05-06  1336276800  0.0035
# 162  2012-05-07  1336363200  0.0000
# 163  2012-05-08  1336449600  0.0000
# 164  2012-05-13  1336881600  0.0000
#
# [165 rows x 3 columns]

# %%
len(dfm)
# Out:
# 992

# %%
dfall = dfm.merge(dfdate, left_on='Date', right_on = 'Date', how= 'left')
len(dfall)
# Out:
# 992

# %%
dfall.head(10)
# Out:
#    Match_ID Div  Season        Date            HomeTeam       AwayTeam  FTHG  \
# 0      1133  D2    2011  2011-07-15             Cottbus        Dresden     2
# 1      1167  D2    2011  2011-07-15      Greuther Furth  Ein Frankfurt     2
# 2      1551  D2    2011  2011-07-15       Frankfurt FSV   Union Berlin     1
# 3      1550  D2    2011  2011-07-16      Erzgebirge Aue         Aachen     1
# 4      1678  D2    2011  2011-07-16            St Pauli     Ingolstadt     2
# 5      1146  D2    2011  2011-07-17           Karlsruhe       Duisburg     3
# 6      1442  D2    2011  2011-07-17        Braunschweig    Munich 1860     3
# 7      1602  D2    2011  2011-07-17       Hansa Rostock      Paderborn     1
# 8      1360  D2    2011  2011-07-18  Fortuna Dusseldorf         Bochum     2
# 9      1505  D2    2011  2011-07-22            Duisburg        Cottbus     1
#
#    FTAG FTR   unix_date    Rain
# 0     1   H  1310702400  0.0000
# 1     3   A  1310702400  0.0000
# 2     1   D  1310702400  0.0000
# 3     0   H  1310788800  0.0000
# 4     0   H  1310788800  0.0000
# 5     2   H  1310875200  0.0180
# 6     1   H  1310875200  0.0180
# 7     2   A  1310875200  0.0180
# 8     0   H  1310961600  0.0100
# 9     2   A  1311307200  0.0489

# %%
dfallr = dfall[(dfall['Rain']>0)]

# %%
dfallr.head()
# Out:
#    Match_ID Div  Season        Date            HomeTeam     AwayTeam  FTHG  \
# 5      1146  D2    2011  2011-07-17           Karlsruhe     Duisburg     3
# 6      1442  D2    2011  2011-07-17        Braunschweig  Munich 1860     3
# 7      1602  D2    2011  2011-07-17       Hansa Rostock    Paderborn     1
# 8      1360  D2    2011  2011-07-18  Fortuna Dusseldorf       Bochum     2
# 9      1505  D2    2011  2011-07-22            Duisburg      Cottbus     1
#
#    FTAG FTR   unix_date    Rain
# 5     2   H  1310875200  0.0180
# 6     1   H  1310875200  0.0180
# 7     2   A  1310875200  0.0180
# 8     0   H  1310961600  0.0100
# 9     2   A  1311307200  0.0489

# %%
dfallah = pd.DataFrame(dfallr.groupby('HomeTeam')['HomeTeam'].count())

# %%
dfallah.columns = ['HomeGameTot']

# %%
dfallah
# Out:
#                     HomeGameTot
# HomeTeam
# Aachen                        5
# Arsenal                       9
# Aston Villa                   9
# Augsburg                      7
# Bayern Munich                 4
# Blackburn                     7
# Bochum                        5
# Bolton                        6
# Braunschweig                  4
# Chelsea                       4
# Cottbus                       5
# Dortmund                      5
# Dresden                       4
# Duisburg                      7
# Ein Frankfurt                 4
# Erzgebirge Aue                7
# Everton                       5
# FC Koln                       8
# Fortuna Dusseldorf            8
# Frankfurt FSV                 8
# Freiburg                      4
# Fulham                        9
# Greuther Furth                6
# Hamburg                       4
# Hannover                      8
# Hansa Rostock                 8
# Hertha                        7
# Hoffenheim                    5
# Ingolstadt                    7
# Kaiserslautern                6
# Karlsruhe                     8
# Leverkusen                    8
# Liverpool                     5
# M'gladbach                    6
# Mainz                         4
# Man City                      8
# Man United                    7
# Munich 1860                   9
# Newcastle                     7
# Norwich                       3
# Nurnberg                      6
# Paderborn                     5
# QPR                           9
# Schalke 04                    3
# St Pauli                      6
# Stoke                         4
# Stuttgart                     4
# Sunderland                    5
# Swansea                       2
# Tottenham                     6
# Union Berlin                  6
# Werder Bremen                 6
# West Brom                     6
# Wigan                         7
# Wolfsburg                     3
# Wolves                        6

# %%
dfallah['AwayGameTot']=dfallr.groupby('AwayTeam')['AwayTeam'].count()

# %%
dfallah
# Out:
#                     HomeGameTot  AwayGameTot
# HomeTeam
# Aachen                        5            8
# Arsenal                       9            5
# Aston Villa                   9            3
# Augsburg                      7            4
# Bayern Munich                 4            7
# Blackburn                     7            3
# Bochum                        5            6
# Bolton                        6            6
# Braunschweig                  4            5
# Chelsea                       4           10
# Cottbus                       5            5
# Dortmund                      5            5
# Dresden                       4            5
# Duisburg                      7            9
# Ein Frankfurt                 4            5
# Erzgebirge Aue                7            4
# Everton                       5            8
# FC Koln                       8            5
# Fortuna Dusseldorf            8            5
# Frankfurt FSV                 8            6
# Freiburg                      4            7
# Fulham                        9            3
# Greuther Furth                6            8
# Hamburg                       4            9
# Hannover                      8            4
# Hansa Rostock                 8            7
# Hertha                        7            3
# Hoffenheim                    5            5
# Ingolstadt                    7            7
# Kaiserslautern                6            6
# Karlsruhe                     8            7
# Leverkusen                    8            6
# Liverpool                     5            5
# M'gladbach                    6            5
# Mainz                         4            6
# Man City                      8            8
# Man United                    7            8
# Munich 1860                   9            8
# Newcastle                     7            6
# Norwich                       3            7
# Nurnberg                      6            3
# Paderborn                     5            7
# QPR                           9            4
# Schalke 04                    3            7
# St Pauli                      6            5
# Stoke                         4            8
# Stuttgart                     4            3
# Sunderland                    5            8
# Swansea                       2            8
# Tottenham                     6            7
# Union Berlin                  6            5
# Werder Bremen                 6            4
# West Brom                     6            8
# Wigan                         7            5
# Wolfsburg                     3            9
# Wolves                        6            4

# %%
dfallhw = dfall[(dfall['Rain']>0) & (dfall['FTR']=='H')]

# %%
dfallhw.head()
# Out:
#     Match_ID Div  Season        Date            HomeTeam       AwayTeam  FTHG  \
# 5       1146  D2    2011  2011-07-17           Karlsruhe       Duisburg     3
# 6       1442  D2    2011  2011-07-17        Braunschweig    Munich 1860     3
# 8       1360  D2    2011  2011-07-18  Fortuna Dusseldorf         Bochum     2
# 11      1667  D2    2011  2011-07-22              Bochum  Frankfurt FSV     1
# 12      1261  D2    2011  2011-07-23         Munich 1860      Karlsruhe     2
#
#     FTAG FTR   unix_date    Rain
# 5      2   H  1310875200  0.0180
# 6      1   H  1310875200  0.0180
# 8      0   H  1310961600  0.0100
# 11     0   H  1311307200  0.0489
# 12     1   H  1311393600  0.0063

# %%
dfallaw = dfall[(dfall['Rain']>0) & (dfall['FTR']=='A')]

# %%
dfallah['HomeWins'] = dfallhw.groupby('HomeTeam')['FTR'].count()

# %%
dfallah['AwayWins'] = dfallaw.groupby('AwayTeam')['FTR'].count()

# %%
dfallah.fillna(0, inplace = True)

# %%
dfallah['RainWinShare'] = round((dfallah['HomeWins']+dfallah['AwayWins'])/(dfallah['HomeGameTot'] + dfallah['AwayGameTot']),2)

# %%
dfallah
# Out:
#                     HomeGameTot  AwayGameTot  HomeWins  AwayWins  RainWinShare
# HomeTeam
# Aachen                        5            8       1.0       2.0          0.23
# Arsenal                       9            5       6.0       2.0          0.57
# Aston Villa                   9            3       1.0       1.0          0.17
# Augsburg                      7            4       4.0       0.0          0.36
# Bayern Munich                 4            7       3.0       5.0          0.73
# Blackburn                     7            3       1.0       0.0          0.10
# Bochum                        5            6       1.0       2.0          0.27
# Bolton                        6            6       1.0       3.0          0.33
# Braunschweig                  4            5       2.0       2.0          0.44
# Chelsea                       4           10       3.0       5.0          0.57
# Cottbus                       5            5       1.0       2.0          0.30
# Dortmund                      5            5       4.0       2.0          0.60
# Dresden                       4            5       3.0       0.0          0.33
# Duisburg                      7            9       3.0       1.0          0.25
# Ein Frankfurt                 4            5       2.0       1.0          0.33
# Erzgebirge Aue                7            4       1.0       0.0          0.09
# Everton                       5            8       2.0       4.0          0.46
# FC Koln                       8            5       3.0       1.0          0.31
# Fortuna Dusseldorf            8            5       4.0       1.0          0.38
# Frankfurt FSV                 8            6       0.0       1.0          0.07
# Freiburg                      4            7       1.0       2.0          0.27
# Fulham                        9            3       4.0       0.0          0.33
# Greuther Furth                6            8       6.0       2.0          0.57
# Hamburg                       4            9       0.0       2.0          0.15
# Hannover                      8            4       5.0       0.0          0.42
# Hansa Rostock                 8            7       0.0       1.0          0.07
# Hertha                        7            3       2.0       1.0          0.30
# Hoffenheim                    5            5       0.0       2.0          0.20
# Ingolstadt                    7            7       1.0       1.0          0.14
# Kaiserslautern                6            6       0.0       0.0          0.00
# Karlsruhe                     8            7       3.0       1.0          0.27
# Leverkusen                    8            6       3.0       3.0          0.43
# Liverpool                     5            5       3.0       1.0          0.40
# M'gladbach                    6            5       4.0       4.0          0.73
# Mainz                         4            6       1.0       1.0          0.20
# Man City                      8            8       7.0       4.0          0.69
# Man United                    7            8       5.0       7.0          0.80
# Munich 1860                   9            8       6.0       5.0          0.65
# Newcastle                     7            6       2.0       1.0          0.23
# Norwich                       3            7       2.0       1.0          0.30
# Nurnberg                      6            3       2.0       3.0          0.56
# Paderborn                     5            7       2.0       4.0          0.50
# QPR                           9            4       3.0       0.0          0.23
# Schalke 04                    3            7       2.0       3.0          0.50
# St Pauli                      6            5       5.0       3.0          0.73
# Stoke                         4            8       2.0       2.0          0.33
# Stuttgart                     4            3       3.0       0.0          0.43
# Sunderland                    5            8       2.0       2.0          0.31
# Swansea                       2            8       1.0       1.0          0.20
# Tottenham                     6            7       5.0       4.0          0.69
# Union Berlin                  6            5       4.0       1.0          0.45
# Werder Bremen                 6            4       4.0       1.0          0.50
# West Brom                     6            8       1.0       3.0          0.29
# Wigan                         7            5       2.0       2.0          0.33
# Wolfsburg                     3            9       2.0       2.0          0.33
# Wolves                        6            4       1.0       0.0          0.10

# %%
df_final = df.merge(dfallah, left_on='teamnames', right_on = 'HomeTeam', how= 'left')
df_final.head()
# Out:
#    id      teamnames  homegoals  awaygoals  homewins  awaywins  homelosses  \
# 0   1         Aachen         15         15         4         2           7
# 1   2        Arsenal         39         35        12         9           3
# 2   3    Aston Villa         20         17         4         3           8
# 3   4       Augsburg         20         16         6         2           4
# 4   5  Bayern Munich         49         28        14         9           2
#
#    awaylosses  totalgoals  totalwins  totalloss  HomeGameTot  AwayGameTot  \
# 0           8          30          6         15          5.0          8.0
# 1           7          74         21         10          9.0          5.0
# 2           6          37          7         14          9.0          3.0
# 3           8          36          8         12          7.0          4.0
# 4           5          77         23          7          4.0          7.0
#
#    HomeWins  AwayWins  RainWinShare
# 0       1.0       2.0          0.23
# 1       6.0       2.0          0.57
# 2       1.0       1.0          0.17
# 3       4.0       0.0          0.36
# 4       3.0       5.0          0.73

# %%
teams, hg, ag, hw, aw, hl, al, rainwin
# Out:
# ['Aachen',
#  'Arsenal',
#  'Aston Villa',
#  'Augsburg',
#  'Bayern Munich',
#  'Blackburn',
#  'Bochum',
#  'Bolton',
#  'Braunschweig',
#  'Chelsea',
#  'Cottbus',
#  'Dortmund',
#  'Dresden',
#  'Duisburg',
#  'Ein Frankfurt',
#  'Erzgebirge Aue',
#  'Everton',
#  'FC Koln',
#  'Fortuna Dusseldorf',
#  'Frankfurt FSV',
#  'Freiburg',
#  'Fulham',
#  'Greuther Furth',
#  'Hamburg',
#  'Hannover',
#  'Hansa Rostock',
#  'Hertha',
#  'Hoffenheim',
#  'Ingolstadt',
#  'Kaiserslautern',
#  'Karlsruhe',
#  'Leverkusen',
#  'Liverpool',
#  "M''gladbach",
#  'Mainz',
#  'Man City',
#  'Man United',
#  'Munich 1860',
#  'Newcastle',
#  'Norwich',
#  'Nurnberg',
#  'Paderborn',
#  'QPR',
#  'Schalke 04',
#  'St Pauli',
#  'Stoke',
#  'Stuttgart',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'Union Berlin',
#  'Werder Bremen',
#  'West Brom',
#  'Wigan',
#  'Wolfsburg',
#  'Wolves']

# %%
teams
# Out:
# ['Aachen',
#  'Arsenal',
#  'Aston Villa',
#  'Augsburg',
#  'Bayern Munich',
#  'Blackburn',
#  'Bochum',
#  'Bolton',
#  'Braunschweig',
#  'Chelsea',
#  'Cottbus',
#  'Dortmund',
#  'Dresden',
#  'Duisburg',
#  'Ein Frankfurt',
#  'Erzgebirge Aue',
#  'Everton',
#  'FC Koln',
#  'Fortuna Dusseldorf',
#  'Frankfurt FSV',
#  'Freiburg',
#  'Fulham',
#  'Greuther Furth',
#  'Hamburg',
#  'Hannover',
#  'Hansa Rostock',
#  'Hertha',
#  'Hoffenheim',
#  'Ingolstadt',
#  'Kaiserslautern',
#  'Karlsruhe',
#  'Leverkusen',
#  'Liverpool',
#  "M''gladbach",
#  'Mainz',
#  'Man City',
#  'Man United',
#  'Munich 1860',
#  'Newcastle',
#  'Norwich',
#  'Nurnberg',
#  'Paderborn',
#  'QPR',
#  'Schalke 04',
#  'St Pauli',
#  'Stoke',
#  'Stuttgart',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'Union Berlin',
#  'Werder Bremen',
#  'West Brom',
#  'Wigan',
#  'Wolfsburg',
#  'Wolves']

# %%
tg = list(df_final['totalgoals'])
tg
# Out:
# [30,
#  74,
#  37,
#  36,
#  77,
#  48,
#  41,
#  46,
#  37,
#  65,
#  30,
#  80,
#  50,
#  42,
#  76,
#  31,
#  50,
#  39,
#  64,
#  43,
#  45,
#  48,
#  73,
#  35,
#  41,
#  34,
#  38,
#  41,
#  43,
#  24,
#  34,
#  52,
#  47,
#  49,
#  47,
#  93,
#  89,
#  62,
#  56,
#  52,
#  38,
#  51,
#  43,
#  74,
#  59,
#  36,
#  63,
#  45,
#  44,
#  66,
#  55,
#  49,
#  45,
#  42,
#  47,
#  40]

# %%
tw = list(df_final['totalwins'])
tw
# Out:
# [6,
#  21,
#  7,
#  8,
#  23,
#  8,
#  10,
#  10,
#  10,
#  18,
#  8,
#  25,
#  12,
#  10,
#  20,
#  8,
#  15,
#  8,
#  16,
#  7,
#  10,
#  14,
#  20,
#  8,
#  12,
#  5,
#  7,
#  10,
#  8,
#  4,
#  9,
#  15,
#  14,
#  17,
#  9,
#  28,
#  28,
#  17,
#  19,
#  12,
#  12,
#  17,
#  10,
#  20,
#  18,
#  11,
#  15,
#  11,
#  12,
#  20,
#  14,
#  11,
#  13,
#  11,
#  13,
#  5]

# %%
rainwin = list(dfallah['RainWinShare'])

# %%
all_results = []
for i in range(0,len(teams)):
    all_results.append({'team_name': teams[i], 'total_goals': tg[i], 'total_wins': tw[i], 'Wins_in_rain_share': rainwin[i]})

# %%
all_results
# Out:
# [{'team_name': 'Aachen',
#   'total_goals': 30,
#   'total_wins': 6,
#   'Wins_in_rain_share': 0.23},
#  {'team_name': 'Arsenal',
#   'total_goals': 74,
#   'total_wins': 21,
#   'Wins_in_rain_share': 0.57},
#  {'team_name': 'Aston Villa',
#   'total_goals': 37,
#   'total_wins': 7,
#   'Wins_in_rain_share': 0.17},
#  {'team_name': 'Augsburg',
#   'total_goals': 36,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.36},
#  {'team_name': 'Bayern Munich',
#   'total_goals': 77,
#   'total_wins': 23,
#   'Wins_in_rain_share': 0.73},
#  {'team_name': 'Blackburn',
#   'total_goals': 48,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.1},
#  {'team_name': 'Bochum',
#   'total_goals': 41,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.27},
#  {'team_name': 'Bolton',
#   'total_goals': 46,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Braunschweig',
#   'total_goals': 37,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.44},
#  {'team_name': 'Chelsea',
#   'total_goals': 65,
#   'total_wins': 18,
#   'Wins_in_rain_share': 0.57},
#  {'team_name': 'Cottbus',
#   'total_goals': 30,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.3},
#  {'team_name': 'Dortmund',
#   'total_goals': 80,
#   'total_wins': 25,
#   'Wins_in_rain_share': 0.6},
#  {'team_name': 'Dresden',
#   'total_goals': 50,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Duisburg',
#   'total_goals': 42,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.25},
#  {'team_name': 'Ein Frankfurt',
#   'total_goals': 76,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Erzgebirge Aue',
#   'total_goals': 31,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.09},
#  {'team_name': 'Everton',
#   'total_goals': 50,
#   'total_wins': 15,
#   'Wins_in_rain_share': 0.46},
#  {'team_name': 'FC Koln',
#   'total_goals': 39,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.31},
#  {'team_name': 'Fortuna Dusseldorf',
#   'total_goals': 64,
#   'total_wins': 16,
#   'Wins_in_rain_share': 0.38},
#  {'team_name': 'Frankfurt FSV',
#   'total_goals': 43,
#   'total_wins': 7,
#   'Wins_in_rain_share': 0.07},
#  {'team_name': 'Freiburg',
#   'total_goals': 45,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.27},
#  {'team_name': 'Fulham',
#   'total_goals': 48,
#   'total_wins': 14,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Greuther Furth',
#   'total_goals': 73,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.57},
#  {'team_name': 'Hamburg',
#   'total_goals': 35,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.15},
#  {'team_name': 'Hannover',
#   'total_goals': 41,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.42},
#  {'team_name': 'Hansa Rostock',
#   'total_goals': 34,
#   'total_wins': 5,
#   'Wins_in_rain_share': 0.07},
#  {'team_name': 'Hertha',
#   'total_goals': 38,
#   'total_wins': 7,
#   'Wins_in_rain_share': 0.3},
#  {'team_name': 'Hoffenheim',
#   'total_goals': 41,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.2},
#  {'team_name': 'Ingolstadt',
#   'total_goals': 43,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.14},
#  {'team_name': 'Kaiserslautern',
#   'total_goals': 24,
#   'total_wins': 4,
#   'Wins_in_rain_share': 0.0},
#  {'team_name': 'Karlsruhe',
#   'total_goals': 34,
#   'total_wins': 9,
#   'Wins_in_rain_share': 0.27},
#  {'team_name': 'Leverkusen',
#   'total_goals': 52,
#   'total_wins': 15,
#   'Wins_in_rain_share': 0.43},
#  {'team_name': 'Liverpool',
#   'total_goals': 47,
#   'total_wins': 14,
#   'Wins_in_rain_share': 0.4},
#  {'team_name': "M''gladbach",
#   'total_goals': 49,
#   'total_wins': 17,
#   'Wins_in_rain_share': 0.73},
#  {'team_name': 'Mainz',
#   'total_goals': 47,
#   'total_wins': 9,
#   'Wins_in_rain_share': 0.2},
#  {'team_name': 'Man City',
#   'total_goals': 93,
#   'total_wins': 28,
#   'Wins_in_rain_share': 0.69},
#  {'team_name': 'Man United',
#   'total_goals': 89,
#   'total_wins': 28,
#   'Wins_in_rain_share': 0.8},
#  {'team_name': 'Munich 1860',
#   'total_goals': 62,
#   'total_wins': 17,
#   'Wins_in_rain_share': 0.65},
#  {'team_name': 'Newcastle',
#   'total_goals': 56,
#   'total_wins': 19,
#   'Wins_in_rain_share': 0.23},
#  {'team_name': 'Norwich',
#   'total_goals': 52,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.3},
#  {'team_name': 'Nurnberg',
#   'total_goals': 38,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.56},
#  {'team_name': 'Paderborn',
#   'total_goals': 51,
#   'total_wins': 17,
#   'Wins_in_rain_share': 0.5},
#  {'team_name': 'QPR',
#   'total_goals': 43,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.23},
#  {'team_name': 'Schalke 04',
#   'total_goals': 74,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.5},
#  {'team_name': 'St Pauli',
#   'total_goals': 59,
#   'total_wins': 18,
#   'Wins_in_rain_share': 0.73},
#  {'team_name': 'Stoke',
#   'total_goals': 36,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Stuttgart',
#   'total_goals': 63,
#   'total_wins': 15,
#   'Wins_in_rain_share': 0.43},
#  {'team_name': 'Sunderland',
#   'total_goals': 45,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.31},
#  {'team_name': 'Swansea',
#   'total_goals': 44,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.2},
#  {'team_name': 'Tottenham',
#   'total_goals': 66,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.69},
#  {'team_name': 'Union Berlin',
#   'total_goals': 55,
#   'total_wins': 14,
#   'Wins_in_rain_share': 0.45},
#  {'team_name': 'Werder Bremen',
#   'total_goals': 49,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.5},
#  {'team_name': 'West Brom',
#   'total_goals': 45,
#   'total_wins': 13,
#   'Wins_in_rain_share': 0.29},
#  {'team_name': 'Wigan',
#   'total_goals': 42,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Wolfsburg',
#   'total_goals': 47,
#   'total_wins': 13,
#   'Wins_in_rain_share': 0.33},
#  {'team_name': 'Wolves',
#   'total_goals': 40,
#   'total_wins': 5,
#   'Wins_in_rain_share': 0.1}]

# %% [markdown]
# ## Mongo

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://127.0.0.1:27017/")
mydb = myclient['mod2proj_final']

# %%
mycol = mydb['mod2proj_final']

# %%
all_results
# Out:
# [{'team_name': 'Aachen',
#   'total_goals': 30,
#   'total_wins': 6,
#   'Wins_in_rain_share': 0.23,
#   '_id': ObjectId('5d19de9272c76097af05913c')},
#  {'team_name': 'Arsenal',
#   'total_goals': 74,
#   'total_wins': 21,
#   'Wins_in_rain_share': 0.57,
#   '_id': ObjectId('5d19de9272c76097af05913d')},
#  {'team_name': 'Aston Villa',
#   'total_goals': 37,
#   'total_wins': 7,
#   'Wins_in_rain_share': 0.17,
#   '_id': ObjectId('5d19de9272c76097af05913e')},
#  {'team_name': 'Augsburg',
#   'total_goals': 36,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.36,
#   '_id': ObjectId('5d19de9272c76097af05913f')},
#  {'team_name': 'Bayern Munich',
#   'total_goals': 77,
#   'total_wins': 23,
#   'Wins_in_rain_share': 0.73,
#   '_id': ObjectId('5d19de9272c76097af059140')},
#  {'team_name': 'Blackburn',
#   'total_goals': 48,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.1,
#   '_id': ObjectId('5d19de9272c76097af059141')},
#  {'team_name': 'Bochum',
#   'total_goals': 41,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.27,
#   '_id': ObjectId('5d19de9272c76097af059142')},
#  {'team_name': 'Bolton',
#   'total_goals': 46,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af059143')},
#  {'team_name': 'Braunschweig',
#   'total_goals': 37,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.44,
#   '_id': ObjectId('5d19de9272c76097af059144')},
#  {'team_name': 'Chelsea',
#   'total_goals': 65,
#   'total_wins': 18,
#   'Wins_in_rain_share': 0.57,
#   '_id': ObjectId('5d19de9272c76097af059145')},
#  {'team_name': 'Cottbus',
#   'total_goals': 30,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.3,
#   '_id': ObjectId('5d19de9272c76097af059146')},
#  {'team_name': 'Dortmund',
#   'total_goals': 80,
#   'total_wins': 25,
#   'Wins_in_rain_share': 0.6,
#   '_id': ObjectId('5d19de9272c76097af059147')},
#  {'team_name': 'Dresden',
#   'total_goals': 50,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af059148')},
#  {'team_name': 'Duisburg',
#   'total_goals': 42,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.25,
#   '_id': ObjectId('5d19de9272c76097af059149')},
#  {'team_name': 'Ein Frankfurt',
#   'total_goals': 76,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af05914a')},
#  {'team_name': 'Erzgebirge Aue',
#   'total_goals': 31,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.09,
#   '_id': ObjectId('5d19de9272c76097af05914b')},
#  {'team_name': 'Everton',
#   'total_goals': 50,
#   'total_wins': 15,
#   'Wins_in_rain_share': 0.46,
#   '_id': ObjectId('5d19de9272c76097af05914c')},
#  {'team_name': 'FC Koln',
#   'total_goals': 39,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.31,
#   '_id': ObjectId('5d19de9272c76097af05914d')},
#  {'team_name': 'Fortuna Dusseldorf',
#   'total_goals': 64,
#   'total_wins': 16,
#   'Wins_in_rain_share': 0.38,
#   '_id': ObjectId('5d19de9272c76097af05914e')},
#  {'team_name': 'Frankfurt FSV',
#   'total_goals': 43,
#   'total_wins': 7,
#   'Wins_in_rain_share': 0.07,
#   '_id': ObjectId('5d19de9272c76097af05914f')},
#  {'team_name': 'Freiburg',
#   'total_goals': 45,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.27,
#   '_id': ObjectId('5d19de9272c76097af059150')},
#  {'team_name': 'Fulham',
#   'total_goals': 48,
#   'total_wins': 14,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af059151')},
#  {'team_name': 'Greuther Furth',
#   'total_goals': 73,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.57,
#   '_id': ObjectId('5d19de9272c76097af059152')},
#  {'team_name': 'Hamburg',
#   'total_goals': 35,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.15,
#   '_id': ObjectId('5d19de9272c76097af059153')},
#  {'team_name': 'Hannover',
#   'total_goals': 41,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.42,
#   '_id': ObjectId('5d19de9272c76097af059154')},
#  {'team_name': 'Hansa Rostock',
#   'total_goals': 34,
#   'total_wins': 5,
#   'Wins_in_rain_share': 0.07,
#   '_id': ObjectId('5d19de9272c76097af059155')},
#  {'team_name': 'Hertha',
#   'total_goals': 38,
#   'total_wins': 7,
#   'Wins_in_rain_share': 0.3,
#   '_id': ObjectId('5d19de9272c76097af059156')},
#  {'team_name': 'Hoffenheim',
#   'total_goals': 41,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.2,
#   '_id': ObjectId('5d19de9272c76097af059157')},
#  {'team_name': 'Ingolstadt',
#   'total_goals': 43,
#   'total_wins': 8,
#   'Wins_in_rain_share': 0.14,
#   '_id': ObjectId('5d19de9272c76097af059158')},
#  {'team_name': 'Kaiserslautern',
#   'total_goals': 24,
#   'total_wins': 4,
#   'Wins_in_rain_share': 0.0,
#   '_id': ObjectId('5d19de9272c76097af059159')},
#  {'team_name': 'Karlsruhe',
#   'total_goals': 34,
#   'total_wins': 9,
#   'Wins_in_rain_share': 0.27,
#   '_id': ObjectId('5d19de9272c76097af05915a')},
#  {'team_name': 'Leverkusen',
#   'total_goals': 52,
#   'total_wins': 15,
#   'Wins_in_rain_share': 0.43,
#   '_id': ObjectId('5d19de9272c76097af05915b')},
#  {'team_name': 'Liverpool',
#   'total_goals': 47,
#   'total_wins': 14,
#   'Wins_in_rain_share': 0.4,
#   '_id': ObjectId('5d19de9272c76097af05915c')},
#  {'team_name': "M''gladbach",
#   'total_goals': 49,
#   'total_wins': 17,
#   'Wins_in_rain_share': 0.73,
#   '_id': ObjectId('5d19de9272c76097af05915d')},
#  {'team_name': 'Mainz',
#   'total_goals': 47,
#   'total_wins': 9,
#   'Wins_in_rain_share': 0.2,
#   '_id': ObjectId('5d19de9272c76097af05915e')},
#  {'team_name': 'Man City',
#   'total_goals': 93,
#   'total_wins': 28,
#   'Wins_in_rain_share': 0.69,
#   '_id': ObjectId('5d19de9272c76097af05915f')},
#  {'team_name': 'Man United',
#   'total_goals': 89,
#   'total_wins': 28,
#   'Wins_in_rain_share': 0.8,
#   '_id': ObjectId('5d19de9272c76097af059160')},
#  {'team_name': 'Munich 1860',
#   'total_goals': 62,
#   'total_wins': 17,
#   'Wins_in_rain_share': 0.65,
#   '_id': ObjectId('5d19de9272c76097af059161')},
#  {'team_name': 'Newcastle',
#   'total_goals': 56,
#   'total_wins': 19,
#   'Wins_in_rain_share': 0.23,
#   '_id': ObjectId('5d19de9272c76097af059162')},
#  {'team_name': 'Norwich',
#   'total_goals': 52,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.3,
#   '_id': ObjectId('5d19de9272c76097af059163')},
#  {'team_name': 'Nurnberg',
#   'total_goals': 38,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.56,
#   '_id': ObjectId('5d19de9272c76097af059164')},
#  {'team_name': 'Paderborn',
#   'total_goals': 51,
#   'total_wins': 17,
#   'Wins_in_rain_share': 0.5,
#   '_id': ObjectId('5d19de9272c76097af059165')},
#  {'team_name': 'QPR',
#   'total_goals': 43,
#   'total_wins': 10,
#   'Wins_in_rain_share': 0.23,
#   '_id': ObjectId('5d19de9272c76097af059166')},
#  {'team_name': 'Schalke 04',
#   'total_goals': 74,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.5,
#   '_id': ObjectId('5d19de9272c76097af059167')},
#  {'team_name': 'St Pauli',
#   'total_goals': 59,
#   'total_wins': 18,
#   'Wins_in_rain_share': 0.73,
#   '_id': ObjectId('5d19de9272c76097af059168')},
#  {'team_name': 'Stoke',
#   'total_goals': 36,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af059169')},
#  {'team_name': 'Stuttgart',
#   'total_goals': 63,
#   'total_wins': 15,
#   'Wins_in_rain_share': 0.43,
#   '_id': ObjectId('5d19de9272c76097af05916a')},
#  {'team_name': 'Sunderland',
#   'total_goals': 45,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.31,
#   '_id': ObjectId('5d19de9272c76097af05916b')},
#  {'team_name': 'Swansea',
#   'total_goals': 44,
#   'total_wins': 12,
#   'Wins_in_rain_share': 0.2,
#   '_id': ObjectId('5d19de9272c76097af05916c')},
#  {'team_name': 'Tottenham',
#   'total_goals': 66,
#   'total_wins': 20,
#   'Wins_in_rain_share': 0.69,
#   '_id': ObjectId('5d19de9272c76097af05916d')},
#  {'team_name': 'Union Berlin',
#   'total_goals': 55,
#   'total_wins': 14,
#   'Wins_in_rain_share': 0.45,
#   '_id': ObjectId('5d19de9272c76097af05916e')},
#  {'team_name': 'Werder Bremen',
#   'total_goals': 49,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.5,
#   '_id': ObjectId('5d19de9272c76097af05916f')},
#  {'team_name': 'West Brom',
#   'total_goals': 45,
#   'total_wins': 13,
#   'Wins_in_rain_share': 0.29,
#   '_id': ObjectId('5d19de9272c76097af059170')},
#  {'team_name': 'Wigan',
#   'total_goals': 42,
#   'total_wins': 11,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af059171')},
#  {'team_name': 'Wolfsburg',
#   'total_goals': 47,
#   'total_wins': 13,
#   'Wins_in_rain_share': 0.33,
#   '_id': ObjectId('5d19de9272c76097af059172')},
#  {'team_name': 'Wolves',
#   'total_goals': 40,
#   'total_wins': 5,
#   'Wins_in_rain_share': 0.1,
#   '_id': ObjectId('5d19de9272c76097af059173')}]

# %%
insertion_results = mycol.insert_many(all_results)

# %%
insertion_results.inserted_ids
# Out:
# [ObjectId('5d19de9272c76097af05913c'),
#  ObjectId('5d19de9272c76097af05913d'),
#  ObjectId('5d19de9272c76097af05913e'),
#  ObjectId('5d19de9272c76097af05913f'),
#  ObjectId('5d19de9272c76097af059140'),
#  ObjectId('5d19de9272c76097af059141'),
#  ObjectId('5d19de9272c76097af059142'),
#  ObjectId('5d19de9272c76097af059143'),
#  ObjectId('5d19de9272c76097af059144'),
#  ObjectId('5d19de9272c76097af059145'),
#  ObjectId('5d19de9272c76097af059146'),
#  ObjectId('5d19de9272c76097af059147'),
#  ObjectId('5d19de9272c76097af059148'),
#  ObjectId('5d19de9272c76097af059149'),
#  ObjectId('5d19de9272c76097af05914a'),
#  ObjectId('5d19de9272c76097af05914b'),
#  ObjectId('5d19de9272c76097af05914c'),
#  ObjectId('5d19de9272c76097af05914d'),
#  ObjectId('5d19de9272c76097af05914e'),
#  ObjectId('5d19de9272c76097af05914f'),
#  ObjectId('5d19de9272c76097af059150'),
#  ObjectId('5d19de9272c76097af059151'),
#  ObjectId('5d19de9272c76097af059152'),
#  ObjectId('5d19de9272c76097af059153'),
#  ObjectId('5d19de9272c76097af059154'),
#  ObjectId('5d19de9272c76097af059155'),
#  ObjectId('5d19de9272c76097af059156'),
#  ObjectId('5d19de9272c76097af059157'),
#  ObjectId('5d19de9272c76097af059158'),
#  ObjectId('5d19de9272c76097af059159'),
#  ObjectId('5d19de9272c76097af05915a'),
#  ObjectId('5d19de9272c76097af05915b'),
#  ObjectId('5d19de9272c76097af05915c'),
#  ObjectId('5d19de9272c76097af05915d'),
#  ObjectId('5d19de9272c76097af05915e'),
#  ObjectId('5d19de9272c76097af05915f'),
#  ObjectId('5d19de9272c76097af059160'),
#  ObjectId('5d19de9272c76097af059161'),
#  ObjectId('5d19de9272c76097af059162'),
#  ObjectId('5d19de9272c76097af059163'),
#  ObjectId('5d19de9272c76097af059164'),
#  ObjectId('5d19de9272c76097af059165'),
#  ObjectId('5d19de9272c76097af059166'),
#  ObjectId('5d19de9272c76097af059167'),
#  ObjectId('5d19de9272c76097af059168'),
#  ObjectId('5d19de9272c76097af059169'),
#  ObjectId('5d19de9272c76097af05916a'),
#  ObjectId('5d19de9272c76097af05916b'),
#  ObjectId('5d19de9272c76097af05916c'),
#  ObjectId('5d19de9272c76097af05916d'),
#  ObjectId('5d19de9272c76097af05916e'),
#  ObjectId('5d19de9272c76097af05916f'),
#  ObjectId('5d19de9272c76097af059170'),
#  ObjectId('5d19de9272c76097af059171'),
#  ObjectId('5d19de9272c76097af059172'),
#  ObjectId('5d19de9272c76097af059173')]

# %%
query_1 = mycol.find({})
for x in query_1:
    print(x)
# Out:
# {'_id': ObjectId('5d19de9272c76097af05913c'), 'team_name': 'Aachen', 'total_goals': 30, 'total_wins': 6, 'Wins_in_rain_share': 0.23}
# {'_id': ObjectId('5d19de9272c76097af05913d'), 'team_name': 'Arsenal', 'total_goals': 74, 'total_wins': 21, 'Wins_in_rain_share': 0.57}
# {'_id': ObjectId('5d19de9272c76097af05913e'), 'team_name': 'Aston Villa', 'total_goals': 37, 'total_wins': 7, 'Wins_in_rain_share': 0.17}
# {'_id': ObjectId('5d19de9272c76097af05913f'), 'team_name': 'Augsburg', 'total_goals': 36, 'total_wins': 8, 'Wins_in_rain_share': 0.36}
# {'_id': ObjectId('5d19de9272c76097af059140'), 'team_name': 'Bayern Munich', 'total_goals': 77, 'total_wins': 23, 'Wins_in_rain_share': 0.73}
# {'_id': ObjectId('5d19de9272c76097af059141'), 'team_name': 'Blackburn', 'total_goals': 48, 'total_wins': 8, 'Wins_in_rain_share': 0.1}
# {'_id': ObjectId('5d19de9272c76097af059142'), 'team_name': 'Bochum', 'total_goals': 41, 'total_wins': 10, 'Wins_in_rain_share': 0.27}
# {'_id': ObjectId('5d19de9272c76097af059143'), 'team_name': 'Bolton', 'total_goals': 46, 'total_wins': 10, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af059144'), 'team_name': 'Braunschweig', 'total_goals': 37, 'total_wins': 10, 'Wins_in_rain_share': 0.44}
# {'_id': ObjectId('5d19de9272c76097af059145'), 'team_name': 'Chelsea', 'total_goals': 65, 'total_wins': 18, 'Wins_in_rain_share': 0.57}
# {'_id': ObjectId('5d19de9272c76097af059146'), 'team_name': 'Cottbus', 'total_goals': 30, 'total_wins': 8, 'Wins_in_rain_share': 0.3}
# {'_id': ObjectId('5d19de9272c76097af059147'), 'team_name': 'Dortmund', 'total_goals': 80, 'total_wins': 25, 'Wins_in_rain_share': 0.6}
# {'_id': ObjectId('5d19de9272c76097af059148'), 'team_name': 'Dresden', 'total_goals': 50, 'total_wins': 12, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af059149'), 'team_name': 'Duisburg', 'total_goals': 42, 'total_wins': 10, 'Wins_in_rain_share': 0.25}
# {'_id': ObjectId('5d19de9272c76097af05914a'), 'team_name': 'Ein Frankfurt', 'total_goals': 76, 'total_wins': 20, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af05914b'), 'team_name': 'Erzgebirge Aue', 'total_goals': 31, 'total_wins': 8, 'Wins_in_rain_share': 0.09}
# {'_id': ObjectId('5d19de9272c76097af05914c'), 'team_name': 'Everton', 'total_goals': 50, 'total_wins': 15, 'Wins_in_rain_share': 0.46}
# {'_id': ObjectId('5d19de9272c76097af05914d'), 'team_name': 'FC Koln', 'total_goals': 39, 'total_wins': 8, 'Wins_in_rain_share': 0.31}
# {'_id': ObjectId('5d19de9272c76097af05914e'), 'team_name': 'Fortuna Dusseldorf', 'total_goals': 64, 'total_wins': 16, 'Wins_in_rain_share': 0.38}
# {'_id': ObjectId('5d19de9272c76097af05914f'), 'team_name': 'Frankfurt FSV', 'total_goals': 43, 'total_wins': 7, 'Wins_in_rain_share': 0.07}
# {'_id': ObjectId('5d19de9272c76097af059150'), 'team_name': 'Freiburg', 'total_goals': 45, 'total_wins': 10, 'Wins_in_rain_share': 0.27}
# {'_id': ObjectId('5d19de9272c76097af059151'), 'team_name': 'Fulham', 'total_goals': 48, 'total_wins': 14, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af059152'), 'team_name': 'Greuther Furth', 'total_goals': 73, 'total_wins': 20, 'Wins_in_rain_share': 0.57}
# {'_id': ObjectId('5d19de9272c76097af059153'), 'team_name': 'Hamburg', 'total_goals': 35, 'total_wins': 8, 'Wins_in_rain_share': 0.15}
# {'_id': ObjectId('5d19de9272c76097af059154'), 'team_name': 'Hannover', 'total_goals': 41, 'total_wins': 12, 'Wins_in_rain_share': 0.42}
# {'_id': ObjectId('5d19de9272c76097af059155'), 'team_name': 'Hansa Rostock', 'total_goals': 34, 'total_wins': 5, 'Wins_in_rain_share': 0.07}
# {'_id': ObjectId('5d19de9272c76097af059156'), 'team_name': 'Hertha', 'total_goals': 38, 'total_wins': 7, 'Wins_in_rain_share': 0.3}
# {'_id': ObjectId('5d19de9272c76097af059157'), 'team_name': 'Hoffenheim', 'total_goals': 41, 'total_wins': 10, 'Wins_in_rain_share': 0.2}
# {'_id': ObjectId('5d19de9272c76097af059158'), 'team_name': 'Ingolstadt', 'total_goals': 43, 'total_wins': 8, 'Wins_in_rain_share': 0.14}
# {'_id': ObjectId('5d19de9272c76097af059159'), 'team_name': 'Kaiserslautern', 'total_goals': 24, 'total_wins': 4, 'Wins_in_rain_share': 0.0}
# {'_id': ObjectId('5d19de9272c76097af05915a'), 'team_name': 'Karlsruhe', 'total_goals': 34, 'total_wins': 9, 'Wins_in_rain_share': 0.27}
# {'_id': ObjectId('5d19de9272c76097af05915b'), 'team_name': 'Leverkusen', 'total_goals': 52, 'total_wins': 15, 'Wins_in_rain_share': 0.43}
# {'_id': ObjectId('5d19de9272c76097af05915c'), 'team_name': 'Liverpool', 'total_goals': 47, 'total_wins': 14, 'Wins_in_rain_share': 0.4}
# {'_id': ObjectId('5d19de9272c76097af05915d'), 'team_name': "M''gladbach", 'total_goals': 49, 'total_wins': 17, 'Wins_in_rain_share': 0.73}
# {'_id': ObjectId('5d19de9272c76097af05915e'), 'team_name': 'Mainz', 'total_goals': 47, 'total_wins': 9, 'Wins_in_rain_share': 0.2}
# {'_id': ObjectId('5d19de9272c76097af05915f'), 'team_name': 'Man City', 'total_goals': 93, 'total_wins': 28, 'Wins_in_rain_share': 0.69}
# {'_id': ObjectId('5d19de9272c76097af059160'), 'team_name': 'Man United', 'total_goals': 89, 'total_wins': 28, 'Wins_in_rain_share': 0.8}
# {'_id': ObjectId('5d19de9272c76097af059161'), 'team_name': 'Munich 1860', 'total_goals': 62, 'total_wins': 17, 'Wins_in_rain_share': 0.65}
# {'_id': ObjectId('5d19de9272c76097af059162'), 'team_name': 'Newcastle', 'total_goals': 56, 'total_wins': 19, 'Wins_in_rain_share': 0.23}
# {'_id': ObjectId('5d19de9272c76097af059163'), 'team_name': 'Norwich', 'total_goals': 52, 'total_wins': 12, 'Wins_in_rain_share': 0.3}
# {'_id': ObjectId('5d19de9272c76097af059164'), 'team_name': 'Nurnberg', 'total_goals': 38, 'total_wins': 12, 'Wins_in_rain_share': 0.56}
# {'_id': ObjectId('5d19de9272c76097af059165'), 'team_name': 'Paderborn', 'total_goals': 51, 'total_wins': 17, 'Wins_in_rain_share': 0.5}
# {'_id': ObjectId('5d19de9272c76097af059166'), 'team_name': 'QPR', 'total_goals': 43, 'total_wins': 10, 'Wins_in_rain_share': 0.23}
# {'_id': ObjectId('5d19de9272c76097af059167'), 'team_name': 'Schalke 04', 'total_goals': 74, 'total_wins': 20, 'Wins_in_rain_share': 0.5}
# {'_id': ObjectId('5d19de9272c76097af059168'), 'team_name': 'St Pauli', 'total_goals': 59, 'total_wins': 18, 'Wins_in_rain_share': 0.73}
# {'_id': ObjectId('5d19de9272c76097af059169'), 'team_name': 'Stoke', 'total_goals': 36, 'total_wins': 11, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af05916a'), 'team_name': 'Stuttgart', 'total_goals': 63, 'total_wins': 15, 'Wins_in_rain_share': 0.43}
# {'_id': ObjectId('5d19de9272c76097af05916b'), 'team_name': 'Sunderland', 'total_goals': 45, 'total_wins': 11, 'Wins_in_rain_share': 0.31}
# {'_id': ObjectId('5d19de9272c76097af05916c'), 'team_name': 'Swansea', 'total_goals': 44, 'total_wins': 12, 'Wins_in_rain_share': 0.2}
# {'_id': ObjectId('5d19de9272c76097af05916d'), 'team_name': 'Tottenham', 'total_goals': 66, 'total_wins': 20, 'Wins_in_rain_share': 0.69}
# {'_id': ObjectId('5d19de9272c76097af05916e'), 'team_name': 'Union Berlin', 'total_goals': 55, 'total_wins': 14, 'Wins_in_rain_share': 0.45}
# {'_id': ObjectId('5d19de9272c76097af05916f'), 'team_name': 'Werder Bremen', 'total_goals': 49, 'total_wins': 11, 'Wins_in_rain_share': 0.5}
# {'_id': ObjectId('5d19de9272c76097af059170'), 'team_name': 'West Brom', 'total_goals': 45, 'total_wins': 13, 'Wins_in_rain_share': 0.29}
# {'_id': ObjectId('5d19de9272c76097af059171'), 'team_name': 'Wigan', 'total_goals': 42, 'total_wins': 11, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af059172'), 'team_name': 'Wolfsburg', 'total_goals': 47, 'total_wins': 13, 'Wins_in_rain_share': 0.33}
# {'_id': ObjectId('5d19de9272c76097af059173'), 'team_name': 'Wolves', 'total_goals': 40, 'total_wins': 5, 'Wins_in_rain_share': 0.1}

# %%
resp = requests.get('https://github.com/phoebetwong/flatiron_mod2proj/blob/phoebe/histgraph.png')
img = resp.content

# %%
img
# Out:
# b'\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-67V2J9Se2CifJlftk9/cExHGvxd7N9b9EdGnQEpszu99Ogeecilu9jIDxoCkx3zNLfB9ArraXW0J03qyVmN0Uw==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-e7318add1f7e055d040edb0f75aaa0ba.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-MRlTIqIyb8caK5+o8llXVntXovciHyAM4qE3kWU2S7SIjAPDxYp4mE0jQp4kP5UYegy+lG9y1I6VlsdzEjb5Qw==" rel="stylesheet" href="https://github.githubassets.com/assets/site-294181adec18ed639e160b96b45d17ac.css" />\n    <link crossorigin="anonymous" media="all" integrity="sha512-3P571Vspzc1UUlXE1URjuTl7D7R7Nc+rrVpvTqGryUtC+VHDSExSBujZ4Zq0MCZSar/FtObOgqOcm0WP/hwzqw==" rel="stylesheet" href="https://github.githubassets.com/assets/github-3068294d3d7a8d980f694e5c220c746e.css" />\n    \n    \n    \n    \n\n  <meta name="viewport" content="width=device-width">\n  \n  <title>flatiron_mod2proj/histgraph.png at phoebe \xc2\xb7 phoebetwong/flatiron_mod2proj \xc2\xb7 GitHub</title>\n    <meta name="description" content="Mod 2 Data Science Project w Joe McAllister. Contribute to phoebetwong/flatiron_mod2proj development by creating an account on GitHub.">\n    <link rel="search" type="application/opensearchdescription+xml" href="/opensearch.xml" title="GitHub">\n  <link rel="fluid-icon" href="https://github.com/fluidicon.png" title="GitHub">\n  <meta property="fb:app_id" content="1401488693436528">\n\n    <meta name="twitter:image:src" content="https://avatars0.githubusercontent.com/u/49416114?s=400&amp;v=4" /><meta name="twitter:site" content="@github" /><meta name="twitter:card" content="summary" /><meta name="twitter:title" content="phoebetwong/flatiron_mod2proj" /><meta name="twitter:description" content="Mod 2 Data Science Project w Joe McAllister. Contribute to phoebetwong/flatiron_mod2proj development by creating an account on GitHub." />\n    <meta property="og:image" content="https://avatars0.githubusercontent.com/u/49416114?s=400&amp;v=4" /><meta property="og:site_name" content="GitHub" /><meta property="og:type" content="object" /><meta property="og:title" content="phoebetwong/flatiron_mod2proj" /><meta property="og:url" content="https://github.com/phoebetwong/flatiron_mod2proj" /><meta property="og:description" content="Mod 2 Data Science Project w Joe McAllister. Contribute to phoebetwong/flatiron_mod2proj development by creating an account on GitHub." />\n\n  <link rel="assets" href="https://github.githubassets.com/">\n  \n  <meta name="pjax-timeout" content="1000">\n  \n  <meta name="request-id" content="DA3C:1E9B:1E44BBD:323E643:5D19DF19" data-pjax-transient>\n\n\n  \n\n  <meta name="selected-link" value="repo_source" data-pjax-transient>\n\n      <meta name="google-site-verification" content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU">\n    <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA">\n    <meta name="google-site-verification" content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc">\n\n  <meta name="octolytics-host" content="collector.githubapp.com" /><meta name="octolytics-app-id" content="github" /><meta name="octolytics-event-url" content="https://collector.githubapp.com/github-external/browser_event" /><meta name="octolytics-dimension-request_id" content="DA3C:1E9B:1E44BBD:323E643:5D19DF19" /><meta name="octolytics-dimension-region_edge" content="iad" /><meta nam ...

# %%
newdict = {'a':4, 'image': img}
mycol.insert_one(newdict)

# %%
_.inserted_id
# Out:
# ObjectId('5d19df1f72c76097af059175')

# %% [markdown]
# # NOTES

# %%
s = 'abc12321cba'

print(s.translate({ord(i): None for i in 'abc'}))
# Out:
# 12321

# %%
tname = []
for t in tables:
    newt = t[0].translate({ord(i): None for i in '(),'})
    tname.append(newt)
tname
# Out:
# ['sqlite_sequence', 'Matches', 'Teams_in_Matches', 'Teams', 'Unique_Teams']

# %%
for t in tables:
    print(t[0])
    c.execute(f"'''select * from {t[0]};'''")
    print(c.description)
# Out:
# sqlite_sequence
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-39-7f5454fbfd4c> in <module>
#       1 for t in tables:
#       2     print(t[0])
# ----> 3     c.execute(f"'''select * from {t[0]};'''")
#       4     print(c.description)
#
# OperationalError: near "'''select * from sqlite_sequence;'''": syntax error

# %%
pd.DataFrame(dfall.groupby('HomeTeam')['rdum'].sum())
# Out:
#                     rdum
# HomeTeam
# Aachen               5.0
# Arsenal              9.0
# Aston Villa          9.0
# Augsburg             7.0
# Bayern Munich        4.0
# Blackburn            7.0
# Bochum               5.0
# Bolton               6.0
# Braunschweig         4.0
# Chelsea              4.0
# Cottbus              5.0
# Dortmund             5.0
# Dresden              4.0
# Duisburg             7.0
# Ein Frankfurt        4.0
# Erzgebirge Aue       7.0
# Everton              5.0
# FC Koln              8.0
# Fortuna Dusseldorf   8.0
# Frankfurt FSV        8.0
# Freiburg             4.0
# Fulham               9.0
# Greuther Furth       6.0
# Hamburg              4.0
# Hannover             8.0
# Hansa Rostock        8.0
# Hertha               7.0
# Hoffenheim           5.0
# Ingolstadt           7.0
# Kaiserslautern       6.0
# Karlsruhe            8.0
# Leverkusen           8.0
# Liverpool            5.0
# M'gladbach           6.0
# Mainz                4.0
# Man City             8.0
# Man United           7.0
# Munich 1860          9.0
# Newcastle            7.0
# Norwich              3.0
# Nurnberg             6.0
# Paderborn            5.0
# QPR                  9.0
# Schalke 04           3.0
# St Pauli             6.0
# Stoke                4.0
# Stuttgart            4.0
# Sunderland           5.0
# Swansea              2.0
# Tottenham            6.0
# Union Berlin         6.0
# Werder Bremen        6.0
# West Brom            6.0
# Wigan                7.0
# Wolfsburg            3.0
# Wolves               6.0
